# %% [markdown]
# #This model uses LSTM to predict a Daily share price movements based on time series and batches of 60 days

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_stock1 = pd.read_csv("../static/data/csl.csv")
# Drop the null columns where all values are null
df_stock2 = df_stock1.dropna(axis='columns', how='all')
# Drop the null rows
df_stock3 = df_stock2.dropna()
# Drop the last rows to test prediction to actual
df_stock_less1= df_stock3.iloc[:-1,:]
# Drop last 3 columns sentiment RBA FED
N=3
df = df_stock_less1.iloc[: , :-N]
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume
# 0  3/01/2000  7.300000  7.300000  7.300000  7.300000   5.234562       0.0
# 1  4/01/2000  7.333333  7.333333  7.066666  7.186666   5.153295  254295.0
# 2  5/01/2000  7.000000  7.183333  7.000000  7.155000   5.130589  424941.0
# 3  6/01/2000  7.233333  7.273333  7.000000  7.000000   5.019443  348534.0
# 4  7/01/2000  7.013000  7.023333  6.800000  6.850000   4.911883  483963.0

# %%
df["Close"].plot()
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5643 entries, 0 to 5677
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5643 non-null   object
#  1   Open       5643 non-null   float64
#  2   High       5643 non-null   float64
#  3   Low        5643 non-null   float64
#  4   Close      5643 non-null   float64
#  5   Adj Close  5643 non-null   float64
#  6   Volume     5643 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 352.7+ KB

# %%
data = df.filter(['Close'])
dataset = data.values
dataset.shape
# Out:
# (5643, 1)

# %% [markdown]
# # # Pre-processing : Scale the data using the MinMaxScaler and split train data

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
dataset_scaled = scaler.fit_transform(dataset)

# Split into train or test
import math
train_data_len = math.ceil(len(dataset)*.8)
train_data = dataset_scaled[0:train_data_len,:]
train_data.shape
# Out:
# (4515, 1)

# %%
X_train = []
y_train = []

for i in range (60, len(train_data)):
    X_train.append(train_data[i-60:i,0]) # contains 60 values
    y_train.append(train_data[i,0])   # contains 61st value
    if i<= 60:
        print(X_train)
        print(y_train)
# Out:
# [array([0.01017412, 0.00983794, 0.00974402, 0.00928425, 0.00883932,
#        0.01027299, 0.01022355, 0.01047074, 0.01037186, 0.01072781,
#        0.01096511, 0.01091567, 0.01096511, 0.01141004, 0.01101454,
#        0.01086623, 0.01081581, 0.01145948, 0.01126173, 0.01135368,
#        0.01145948, 0.01150891, 0.01154846, 0.01155835, 0.01160779,
#        0.01096511, 0.01111342, 0.01126173, 0.01056961, 0.01041141,
#        0.01037186, 0.01003569, 0.00937719, 0.00899653, 0.00903707,
#        0.00898763, 0.00898763, 0.00943256, 0.00933369, 0.009482  ,
#        0.01007524, 0.00999515, 0.009482  , 0.00862773, 0.00918538,
#        0.00928425, 0.00898763, 0.00903707, 0.0097806 , 0.00997637,
#        0.00997637, 0.00997637, 0.01037186, 0.01032243, 0.01039362,
#        0.01056961, 0.01066848, 0.01047074, 0.01027299, 0.01047074])]
# [0.010477658470026397]

# %% [markdown]
# # Prepare train data for LSTM model

# %%
# Convert list to numpy array for LSTM model:
X_train, y_train = np.array(X_train), np.array(y_train)
X_train.shape
# Out:
# (4455, 60)

# %%
# LSTM model expects 3D, reshape:
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (4455, 60, 1)

# %% [markdown]
# # Build the LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, batch_size=1, epochs=1)
# Out:
# 4455/4455 [==============================] - 54s 12ms/step - loss: 2.1424e-04

# %%
#Create test data
test_data = dataset_scaled[train_data_len-60:,:]
X_test = []
y_test = dataset[train_data_len:,:]
for i in range(60, len(test_data)):
 X_test.append(test_data[i-60:i,0])

# %%
#Covert test data to a numpy array and reshape
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

# %%
#Get predicted prices
predictions_lstm = model.predict(X_test)
predictions = scaler.inverse_transform(predictions_lstm)

# %%
#Get the root mean square error (RMSE) 0 being most favourable
rmse = np.sqrt(np.mean(predictions-y_test)**2)
rmse
# Out:
# 9.474548126251007

# %%
#Plot the data to validate the test data
plt.style.use('fivethirtyeight')
train = data.iloc[:train_data_len] # actual train data from 0 rows until train data end
valid = data.iloc[train_data_len:] # actual test data from train data end until end of all sampled data
valid['Predictions'] = predictions # another column for validating test

plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price AUD ($)',fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
plt.legend(['Training','Validate','Predictions'],loc='lower right')
plt.show()
# Out:
# C:\Users\antoi\AppData\Local\Temp/ipykernel_4208/2718277095.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions # another column for validating test

# %% [markdown]
# # Test data Predictions on the Model

# %%
valid['Difference']= valid['Close']-valid['Predictions']
valid
# Out:
# C:\Users\antoi\AppData\Local\Temp/ipykernel_4208/3952761259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Difference']= valid['Close']-valid['Predictions']
#            Close  Predictions  Difference
# 4550  140.419998   137.059723    3.360275
# 4551  140.990005   137.151047    3.838958
# 4552  143.020004   137.327057    5.692947
# 4553  144.589996   137.752136    6.837860
# 4554  144.270004   138.419968    5.850036
# ...          ...          ...         ...
# 5673  265.470001   257.080536    8.389465
# 5674  261.970001   256.820862    5.149139
# 5675  262.959991   256.154907    6.805084
# 5676  264.950012   255.524689    9.425323
# 5677  262.350006   255.195160    7.154846
#
# [1128 rows x 3 columns]

# %%
#Get latest 60 quotes less 1 to predict:

#import pandas_datareader.data as web
#symbol = 'CSL.AX'
#stock_quote = web.DataReader(symbol,data_source='yahoo',start='2022-01-01', end='2022-04-13')
#stock_quotes_sixty = stock_quotes_sixty.filter(['Close'])
#stock_quotes_sixty
#OR use csv data

# %%
# Use last 60 days price on model to predict next days price
stock_quotes_sixty = df_stock_less1.tail(60)
stock_close_sixty = stock_quotes_sixty['Close']
last_60_days = stock_close_sixty[-60:].values
last_60_days = last_60_days.reshape(-1,1)
last_60_days.shape

# %%
last_60_days_scaled = scaler.transform(last_60_days)
X_tell = []
X_tell.append(last_60_days_scaled)
X_tell =np.array(X_tell)
X_tell =np.reshape(X_tell, (X_tell.shape[0], X_tell.shape[1],1))
X_tell.shape
# Out:
# Predicted next day share price 254

# %%
pred_price = model.predict(X_tell)
pred_price = scaler.inverse_transform(pred_price)
pred_price = int(pred_price)
print(f'Predicted next day share price {pred_price}')

# %%
#stock_quote_acual = web.DataReader('CSL.AX',data_source='yahoo',start='2022-04-14', end='2022-04-14')
#OR get last quote from latest csv
stock_quote_last_one = df_stock1.tail(1)
stock_quote_last_one
# Out:
#             Date        Open       High         Low  Close  Adj Close  \
# 5678  20/04/2022  266.100006  267.98999  263.700012  264.5      264.5
#
#         Volume SENTIMENT   RBA   FED
# 5678  857150.0  NEGATIVE  0.05  0.08

# %%
#save actual to variable
actual_price = stock_quote_last_one.iloc[0,4]
actual_date = stock_quote_last_one.iloc[0,0] 
actual_price = int(actual_price)
actual_price
actual_date
# Out:
# '20/04/2022'

# %% [markdown]
# # Save the Model

# %%
# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
filepath = '../static/csl_model.sav'
model.save(filepath, save_format="h5")

# %% [markdown]
# #Save last 60 days to a list csl_sixty and load df

# %%
# Read in the CSV file
df_csl_sixty = pd.read_csv("../static/data/csl_sixty.csv")
df_csl_sixty.head()

# %%
close_sixty_val = df_csl_sixty[-60:].values
last_sixty = close_sixty_val.reshape(-1,1)
last_sixty.shape

# %%
last_sixty_scaled = scaler.transform(last_sixty)
new_X_tell = []
new_X_tell.append(last_sixty_scaled)
new_X_tell =np.array(new_X_tell)
new_X_tell =np.reshape(new_X_tell, (new_X_tell.shape[0], new_X_tell.shape[1],1))
new_X_tell.shape

# %% [markdown]
# #PREDICT USING LOADED MODEL

# %%
from keras.models import load_model
model_in = load_model('../static/csl_model.sav')

# %%
model_in_pd_scale = model_in.predict(new_X_tell)
model_in_pd_scale

# %%
model_in_price = scaler.inverse_transform(model_in_pd_scale)
#model_in_price_int = int(model_in_price)
print(f'Predicted next day share price {model_in_price}')

# %%
last_sixty_less_one = np.delete(last_sixty, 0, 0)
last_sixty_less_one.shape

# %%
last_sixty = np.append(last_sixty_less_one, model_in_price,axis = 0)
last_sixty.shape

# %% [markdown]
# #Create a function to loop through the days input

# %%
from keras.models import load_model
model_in = load_model('../static/csl_model.sav')
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
# Read in the CSV file
df_csl_sixty = pd.read_csv("../static/data/csl_sixty.csv")
close_sixty_val = df_csl_sixty[-60:].values
last_sixty = close_sixty_val.reshape(-1,1)
price_list=[]

#Function to predict future days predicted price, in loop
input = 80 #days
if input == "":
    input = 1
else:
   input = int(input)

def predict_csl(last_sixty,model_in,input):
    for i in range(1, input):

        #Takes df and converts to model's predict shape
        last_sixty_scaled = scaler.fit_transform(last_sixty)
        new_X_tell = []
        new_X_tell.append(last_sixty_scaled)
        new_X_tell =np.array(new_X_tell)
        new_X_tell =np.reshape(new_X_tell, (new_X_tell.shape[0], new_X_tell.shape[1],1))
        
        model_in_pd_scale = model_in.predict(new_X_tell)
        model_in_price = scaler.inverse_transform(model_in_pd_scale) # New price predicted

        last_sixty_less_one = np.delete(last_sixty, 0, 0)
        last_sixty = np.append(last_sixty_less_one, model_in_price,axis = 0) # Update last 60
        print(i)
        print("Day finished! Price: ")
        price_float = float(model_in_price)
        price = round(price_float, 2)
        price_list.append(price)
    else:
        print("Could not predict further!")
        print(input)
    print(price_list)

# %%
predict_csl(last_sixty,model_in,input)

# %% [markdown]
# #Save predicted price to MongoDB

# %%
# # Module used to connect Python with MongoDb
# import pymongo

# %%
# # The default port used by MongoDB is 27017
# # https://docs.mongodb.com/manual/reference/default-mongodb-port/
# conn = 'mongodb://localhost:27017'
# client = pymongo.MongoClient(conn)

# # Define the 'sharesDB' database in Mongo
# db = client.sharesDB

# %%
# # Query all
# # Here, db.companys refers to the collection 'companys '
# companys = db.companys.find()

# # Iterate through each company in the collection
# for company in companys:
#     print(company)
# Out:
# {'_id': ObjectId('6264fbd42e2e09a809a86cac'), 'model': 'LSTM', 'name': 'CBA', 'date': '14/04/2022', 'predicted': 100, 'actual': 106, 'differece': -6}
# {'_id': ObjectId('6264ff16df07389eadcbc16d'), 'model': 'LSTM', 'name': 'BHP', 'date': '14/04/2022', 'predicted': 47, 'actual': 52, 'differece': -5}
# {'_id': ObjectId('626501370c82845407aeb22d'), 'model': 'LSTM', 'name': 'NAB', 'date': '14/04/2022', 'predicted': 33, 'actual': 32, 'differece': 1}

# %%
# # Set keys and values of company
# name = 'CSL'
# predicted = int(pred_price)
# difference = pred_price-actual_price
# print(f'date {actual_date},predicted {predicted},actual {actual_price}, difference {difference}')
# Out:
# date 20/04/2022,predicted 254,actual 264, difference -10

# %%
# # Insert a document into the 'companys' collection
# db.companys.insert_one(
#     {
#       'model': 'LSTM',
#       'name': name,
#       'date': actual_date,
#       'predicted': predicted,
#       'actual': actual_price,
#       'differece': difference
#     }
# )

# # query the classroom collection
# companys = db.companys.find()

# # see change in collection
# for company in companys:
#     print(company)
# Out:
# {'_id': ObjectId('6264fbd42e2e09a809a86cac'), 'model': 'LSTM', 'name': 'CBA', 'date': '14/04/2022', 'predicted': 100, 'actual': 106, 'differece': -6}
# {'_id': ObjectId('6264ff16df07389eadcbc16d'), 'model': 'LSTM', 'name': 'BHP', 'date': '14/04/2022', 'predicted': 47, 'actual': 52, 'differece': -5}
# {'_id': ObjectId('626501370c82845407aeb22d'), 'model': 'LSTM', 'name': 'NAB', 'date': '14/04/2022', 'predicted': 33, 'actual': 32, 'differece': 1}
# {'_id': ObjectId('6265026f632b6c5eed85b5c5'), 'model': 'LSTM', 'name': 'CSL', 'date': '20/04/2022', 'predicted': 254, 'actual': 264, 'differece': -10}

# %%
# # Delete a document from a collection
# db.companys.delete_one(
#     {'name': 'CSL'}
# )

# # query the companys collection
# companys = db.companys.find()

# # see change in the collection
# for company in companys:
#     print(company)

# %%
# from pymongo import MongoClient
# mongoClient = MongoClient()
# db = mongoClient.sharesDB
# db.csl.drop()

# import csv
# header = ["Date","Open","High","Low","Close","Adj Close","Volume","SENTIMENT","RBA","FED"]
# csvfile = open('../static/data/csl.csv', 'r')
# reader = csv.DictReader( csvfile )

# for each in reader:
#     row={}
#     for field in header:
#         row[field]=each[field]
        
#     print (row)
#     db.csl.insert_one(row)
# Out:
# {'Date': '3/01/2000', 'Open': '7.3', 'High': '7.3', 'Low': '7.3', 'Close': '7.3', 'Adj Close': '5.234562', 'Volume': '0', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '4/01/2000', 'Open': '7.333333', 'High': '7.333333', 'Low': '7.066666', 'Close': '7.186666', 'Adj Close': '5.153295', 'Volume': '254295', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '5/01/2000', 'Open': '7', 'High': '7.183333', 'Low': '7', 'Close': '7.155', 'Adj Close': '5.130589', 'Volume': '424941', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '6/01/2000', 'Open': '7.233333', 'High': '7.273333', 'Low': '7', 'Close': '7', 'Adj Close': '5.019443', 'Volume': '348534', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '7/01/2000', 'Open': '7.013', 'High': '7.023333', 'Low': '6.8', 'Close': '6.85', 'Adj Close': '4.911883', 'Volume': '483963', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '10/01/2000', 'Open': '7', 'High': '7.333333', 'Low': '7', 'Close': '7.333333', 'Adj Close': '5.258464', 'Volume': '546525', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '11/01/2000', 'Open': '7.333333', 'High': '7.333333', 'Low': '7.233333', 'Close': '7.316666', 'Adj Close': '5.246511', 'Volume': '870903', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '12/01/2000', 'Open': '7.166666', 'High': '7.4', 'Low': '7.166666', 'Close': '7.4', 'Adj Close': '5.306267', 'Volume': '321720', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '13/01/2000', 'Open': '7.366666', 'High': '7.466666', 'Low': '7.3', 'Close': '7.366666', 'Adj Close': '5.282365', 'Volume': '565902', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '14/01/2000', 'Open': '7.333333', 'High': '7.496666', 'Low': '7.333333', 'Close': '7.486666', 'Adj Close': '5.368413', 'Volume': '551202', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '17/01/2000', 'Open': '7.48', 'High': '7.716666', 'Low': '7.466666', 'Close': '7.566666', 'Adj Close': '5.425777', 'Volume': '1372908', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '18/01/2000', 'Open': '7.566666', 'High': '7.566666', 'Low': '7.43', 'Close': '7.55', 'Adj Close': '5.413829', 'Volume': '514509', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '19/01/2000', 'Open': '7.533333', 'High': '7.566666', 'Low': '7.42', 'Close': '7.566666', 'Adj Close': '5.425777', 'Volume': '365580', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '20/01/2000', 'Open': '7.533333', 'High': '7.733333', 'Low': '7.53', 'Close': '7.716666', 'Adj Close': '5.533338', 'Volume': '1940439', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '21/01/2000', 'Open': '7.583333', 'High': '7.683333', 'Low': '7.58', 'Close': '7.583333', 'Adj Close': '5.43773', 'Volume': '407316', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '24/01/2000', 'Open': '7.533333', 'High': '7.593333', 'Low': '7.516666', 'Close': '7.533333', 'Adj Close': '5.401875', 'Volume': '213306', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '25/01/2000', 'Open': '7.529', 'High': '7.529', 'Low': '7.466666', 'Close': '7.516333', 'Adj Close': '5.389686', 'Volume': '1039110', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '26/01/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '27/01/2000', 'Open': '7.534', 'High': '7.8', 'Low': '7.533333', 'Close': '7.733333', 'Adj Close': '5.545289', 'Volume': '929907', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '28/01/2000', 'Open': '7.720666', 'High': '7.720666', 'Low': '7.666666', 'Close': '7.666666', 'Adj Close': '5.497485', 'Volume': '280431', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '31/01/2000', 'Open': '7.655333', 'High': '7.733333', 'Low': '7.55', 'Close': '7.697666', 'Adj Close': '5.519713', 'Volume': '778572', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'Date': '1/02/2000', 'Open': '7.7', 'High': '7.766666', 'Low': '7.7', 'Close': '7.733333', 'Adj Close': '5.545289', 'Volume': '527550', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '2/02/2000', 'Open': '7.783333', 'High': '7.783333', 'Low': '7.633333', 'Close': '7.75', 'Adj Close': '5.55724', 'Volume': '218361', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '3/02/2000', 'Open': '7.669', 'High': '7.8', 'Low': '7.669', 'Close': '7.763333', 'Adj Close': '5.566802', 'Volume': '369984', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '4/02/2000', 'Open': '7.759666', 'High': '7.85', 'Low': '7.726666', 'Close': '7.766666', 'Adj Close': '5.569191', 'Volume': '474762', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '7/02/2000', 'Open': '7.732', 'High': '7.816666', 'Low': '7.732', 'Close': '7.783333', 'Adj Close': '5.581141', 'Volume': '360501', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '8/02/2000', 'Open': '7.735333', 'High': '7.75', 'Low': '7.533333', 'Close': '7.566666', 'Adj Close': '5.425777', 'Volume': '495267', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '9/02/2000', 'Open': '7.533', 'High': '7.666666', 'Low': '7.533', 'Close': '7.616666', 'Adj Close': '5.461631', 'Volume': '465558', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '10/02/2000', 'Open': '7.616666', 'High': '7.683333', 'Low': '7.583333', 'Close': '7.666666', 'Adj Close': '5.497485', 'Volume': '2397987', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '11/02/2000', 'Open': '7.666666', 'High': '7.666666', 'Low': '7.38', 'Close': '7.433333', 'Adj Close': '5.330169', 'Volume': '1005972', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '14/02/2000', 'Open': '7.410333', 'High': '7.410333', 'Low': '7.363333', 'Close': '7.38', 'Adj Close': '5.291926', 'Volume': '469875', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '15/02/2000', 'Open': '7.346333', 'High': '7.366666', 'Low': '7.3', 'Close': '7.366666', 'Adj Close': '5.282365', 'Volume': '1430886', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '16/02/2000', 'Open': '7.434333', 'High': '7.434333', 'Low': '7.193333', 'Close': '7.253333', 'Adj Close': '5.201099', 'Volume': '618939', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '17/02/2000', 'Open': '7.166666', 'High': '7.166666', 'Low': '7', 'Close': '7.031333', 'Adj Close': '5.041911', 'Volume': '764163', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '18/02/2000', 'Open': '7.029666', 'High': '7.033333', 'Low': '6.833333', 'Close': '6.903', 'Adj Close': '4.949886', 'Volume': '672681', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '21/02/2000', 'Open': '6.668666', 'High': '6.95', 'Low': '6.668666', 'Close': '6.916666', 'Adj Close': '4.959687', 'Volume': '320697', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '22/02/2000', 'Open': '6.913666', 'High': '6.916666', 'Low': '6.866666', 'Close': '6.9', 'Adj Close': '4.947737', 'Volume': '582369', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '23/02/2000', 'Open': '6.9', 'High': '7.1', 'Low': '6.883333', 'Close': '6.9', 'Adj Close': '4.947737', 'Volume': '228966', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '24/02/2000', 'Open': '6.9', 'High': '7.116666', 'Low': '6.9', 'Close': '7.05', 'Adj Close': '5.055296', 'Volume': '983379', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '25/02/2000', 'Open': '7.096666', 'High': '7.096666', 'Low': '6.966666', 'Close': '7.016666', 'Adj Close': '5.031394', 'Volume': '291414', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '28/02/2000', 'Open': '6.9', 'High': '7.083333', 'Low': '6.9', 'Close': '7.066666', 'Adj Close': '5.067247', 'Volume': '573717', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '29/02/2000', 'Open': '7.086666', 'High': '7.266666', 'Low': '7.086666', 'Close': '7.266666', 'Adj Close': '5.210659', 'Volume': '799758', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'Date': '1/03/2000', 'Open': '7.236', 'High': '7.283333', 'Low': '7.166666', 'Close': '7.239666', 'Adj Close': '5.191299', 'Volume': '219144', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '2/03/2000', 'Open': '7.266666', 'High': '7.266666', 'Low': '7', 'Close': '7.066666', 'Adj Close': '5.067247', 'Volume': '163251', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '3/03/2000', 'Open': '6.833333', 'High': '6.833333', 'Low': '6.5', 'Close': '6.778666', 'Adj Close': '4.860732', 'Volume': '754611', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '6/03/2000', 'Open': '6.902666', 'High': '7.066666', 'Low': '6.866666', 'Close': '6.966666', 'Adj Close': '4.995541', 'Volume': '1271727', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '7/03/2000', 'Open': '6.921', 'High': '7.066666', 'Low': '6.9', 'Close': '7', 'Adj Close': '5.019443', 'Volume': '673557', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '8/03/2000', 'Open': '6.933333', 'High': '6.983333', 'Low': '6.866666', 'Close': '6.9', 'Adj Close': '4.947737', 'Volume': '137508', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '9/03/2000', 'Open': '6.916666', 'High': '7.266666', 'Low': '6.916666', 'Close': '6.916666', 'Adj Close': '4.959687', 'Volume': '544968', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '10/03/2000', 'Open': '7.018333', 'High': '7.21', 'Low': '7.018333', 'Close': '7.167333', 'Adj Close': '5.139433', 'Volume': '542694', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '13/03/2000', 'Open': '7.2', 'High': '7.333333', 'Low': '7.2', 'Close': '7.233333', 'Adj Close': '5.186757', 'Volume': '484104', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '14/03/2000', 'Open': '7.166666', 'High': '7.283333', 'Low': '7.166666', 'Close': '7.233333', 'Adj Close': '5.186757', 'Volume': '306072', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '15/03/2000', 'Open': '7.166666', 'High': '7.3', 'Low': '7.066666', 'Close': '7.233333', 'Adj Close': '5.186757', 'Volume': '346368', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '16/03/2000', 'Open': '7.236333', 'High': '7.596666', 'Low': '7.236333', 'Close': '7.366666', 'Adj Close': '5.282365', 'Volume': '1253349', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '17/03/2000', 'Open': '7.388', 'High': '7.433333', 'Low': '7.323333', 'Close': '7.35', 'Adj Close': '5.270415', 'Volume': '472059', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '20/03/2000', 'Open': '7.341', 'High': '7.374', 'Low': '7.3', 'Close': '7.374', 'Adj Close': '5.287624', 'Volume': '414312', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '21/03/2000', 'Open': '7.334', 'High': '7.433333', 'Low': '7.263333', 'Close': '7.433333', 'Adj Close': '5.330169', 'Volume': '311436', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '22/03/2000', 'Open': '7.437666', 'High': '7.583333', 'Low': '7.433333', 'Close': '7.466666', 'Adj Close': '5.354072', 'Volume': '552117', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '23/03/2000', 'Open': '7.366666', 'High': '7.4', 'Low': '7.333333', 'Close': '7.4', 'Adj Close': '5.306267', 'Volume': '327612', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '24/03/2000', 'Open': '7.4', 'High': '7.4', 'Low': '7.216666', 'Close': '7.333333', 'Adj Close': '5.258464', 'Volume': '222291', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '27/03/2000', 'Open': '7.333333', 'High': '7.5', 'Low': '7.333333', 'Close': '7.4', 'Adj Close': '5.306267', 'Volume': '2543211', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '28/03/2000', 'Open': '7.433333', 'High': '7.5', 'Low': '7.383333', 'Close': '7.402333', 'Adj Close': '5.307941', 'Volume': '259686', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '29/03/2000', 'Open': '7.35', 'High': '7.433333', 'Low': '7.233333', 'Close': '7.25', 'Adj Close': '5.198709', 'Volume': '224685', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '30/03/2000', 'Open': '7.31', 'High': '7.31', 'Low': '6.965', 'Close': '6.965', 'Adj Close': '4.994346', 'Volume': '511386', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '31/03/2000', 'Open': '6.833333', 'High': '6.9', 'Low': '6.666666', 'Close': '6.833333', 'Adj Close': '4.899931', 'Volume': '587913', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'Date': '3/04/2000', 'Open': '6.821333', 'High': '7.133333', 'Low': '6.803333', 'Close': '7.1', 'Adj Close': '5.09115', 'Volume': '544389', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '4/04/2000', 'Open': '7.1', 'High': '7.1', 'Low': '6.663333', 'Close': '6.731666', 'Adj Close': '4.82703', 'Volume': '766302', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '5/04/2000', 'Open': '6.733333', 'High': '6.733333', 'Low': '6.556666', 'Close': '6.578333', 'Adj Close': '4.717082', 'Volume': '690708', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '6/04/2000', 'Open': '6.666666', 'High': '6.666666', 'Low': '6.566666', 'Close': '6.567333', 'Adj Close': '4.728361', 'Volume': '1601097', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '7/04/2000', 'Open': '6.6', 'High': '6.733333', 'Low': '6.6', 'Close': '6.7', 'Adj Close': '4.823878', 'Volume': '844500', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '10/04/2000', 'Open': '6.733333', 'High': '6.766666', 'Low': '6.683333', 'Close': '6.766666', 'Adj Close': '4.871877', 'Volume': '1203087', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '11/04/2000', 'Open': '6.75', 'High': '6.786666', 'Low': '6.666666', 'Close': '6.75', 'Adj Close': '4.859879', 'Volume': '702621', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '12/04/2000', 'Open': '6.75', 'High': '7.033333', 'Low': '6.75', 'Close': '7.033333', 'Adj Close': '5.063872', 'Volume': '873501', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '13/04/2000', 'Open': '7.03', 'High': '7.03', 'Low': '6.79', 'Close': '6.9', 'Adj Close': '4.967873', 'Volume': '333651', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '14/04/2000', 'Open': '6.866666', 'High': '7', 'Low': '6.866666', 'Close': '6.973333', 'Adj Close': '5.020672', 'Volume': '187020', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '17/04/2000', 'Open': '6.483', 'High': '6.666666', 'Low': '6.433333', 'Close': '6.636666', 'Adj Close': '4.778279', 'Volume': '901707', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '18/04/2000', 'Open': '6.833333', 'High': '6.9', 'Low': '6.766666', 'Close': '6.816666', 'Adj Close': '4.907876', 'Volume': '1093224', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '19/04/2000', 'Open': '6.829666', 'High': '6.833333', 'Low': '6.773333', 'Close': '6.8', 'Adj Close': '4.895877', 'Volume': '902730', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '20/04/2000', 'Open': '6.8', 'High': '6.833333', 'Low': '6.733333', 'Close': '6.8', 'Adj Close': '4.895877', 'Volume': '740607', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '21/04/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '24/04/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '25/04/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '26/04/2000', 'Open': '6.703333', 'High': '6.916666', 'Low': '6.703333', 'Close': '6.85', 'Adj Close': '4.931876', 'Volume': '149985', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '27/04/2000', 'Open': '6.85', 'High': '6.85', 'Low': '6.75', 'Close': '6.783333', 'Adj Close': '4.883877', 'Volume': '940434', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '28/04/2000', 'Open': '6.766666', 'High': '6.883333', 'Low': '6.633333', 'Close': '6.866666', 'Adj Close': '4.943877', 'Volume': '349632', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'Date': '1/05/2000', 'Open': '6.868666', 'High': '6.9', 'Low': '6.816666', 'Close': '6.816666', 'Adj Close': '4.907876', 'Volume': '249135', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '2/05/2000', 'Open': '6.83', 'High': '7', 'Low': '6.83', 'Close': '7', 'Adj Close': '5.039874', 'Volume': '171507', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '3/05/2000', 'Open': '7.001', 'High': '7.066666', 'Low': '6.906666', 'Close': '7.016666', 'Adj Close': '5.051873', 'Volume': '257940', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '4/05/2000', 'Open': '6.993666', 'High': '6.993666', 'Low': '6.866666', 'Close': '6.866666', 'Adj Close': '4.943877', 'Volume': '57879', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '5/05/2000', 'Open': '6.817', 'High': '7', 'Low': '6.817', 'Close': '7', 'Adj Close': '5.039874', 'Volume': '334863', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '8/05/2000', 'Open': '7.008', 'High': '7.166666', 'Low': '6.866666', 'Close': '7', 'Adj Close': '5.039874', 'Volume': '305301', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '9/05/2000', 'Open': '7', 'High': '7.1', 'Low': '7', 'Close': '7.02', 'Adj Close': '5.054274', 'Volume': '195366', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '10/05/2000', 'Open': '7', 'High': '7.03', 'Low': '6.9', 'Close': '7', 'Adj Close': '5.039874', 'Volume': '211260', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '11/05/2000', 'Open': '6.922666', 'High': '6.922666', 'Low': '6.666666', 'Close': '6.8', 'Adj Close': '4.895877', 'Volume': '352203', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '12/05/2000', 'Open': '6.833333', 'High': '6.866666', 'Low': '6.833333', 'Close': '6.86', 'Adj Close': '4.939076', 'Volume': '271482', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '15/05/2000', 'Open': '6.833333', 'High': '6.833333', 'Low': '6.733333', 'Close': '6.733333', 'Adj Close': '4.847879', 'Volume': '1288014', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '16/05/2000', 'Open': '6.75', 'High': '6.75', 'Low': '6.65', 'Close': '6.672333', 'Adj Close': '4.803959', 'Volume': '265869', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '17/05/2000', 'Open': '6.697333', 'High': '6.783333', 'Low': '6.696666', 'Close': '6.766666', 'Adj Close': '4.871877', 'Volume': '376725', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '18/05/2000', 'Open': '6.75', 'High': '6.8', 'Low': '6.7', 'Close': '6.766666', 'Adj Close': '4.871877', 'Volume': '423822', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '19/05/2000', 'Open': '6.764333', 'High': '6.766666', 'Low': '6.616666', 'Close': '6.693333', 'Adj Close': '4.819079', 'Volume': '186585', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '22/05/2000', 'Open': '6.694', 'High': '6.694', 'Low': '6.623333', 'Close': '6.683333', 'Adj Close': '4.811879', 'Volume': '279186', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '23/05/2000', 'Open': '6.666666', 'High': '6.7', 'Low': '6.66', 'Close': '6.666666', 'Adj Close': '4.799879', 'Volume': '314550', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '24/05/2000', 'Open': '6.65', 'High': '6.733333', 'Low': '6.633333', 'Close': '6.733333', 'Adj Close': '4.847879', 'Volume': '1207137', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '25/05/2000', 'Open': '6.766666', 'High': '7.05', 'Low': '6.733333', 'Close': '7.033333', 'Adj Close': '5.063872', 'Volume': '861078', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '26/05/2000', 'Open': '6.866666', 'High': '7.266666', 'Low': '6.866666', 'Close': '7.213', 'Adj Close': '5.193228', 'Volume': '1058268', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '29/05/2000', 'Open': '7.183333', 'High': '7.416666', 'Low': '7.183333', 'Close': '7.37', 'Adj Close': '5.306265', 'Volume': '254409', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '30/05/2000', 'Open': '7.402333', 'High': '7.533333', 'Low': '7.4', 'Close': '7.533333', 'Adj Close': '5.423863', 'Volume': '300171', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '31/05/2000', 'Open': '7.603333', 'High': '7.9', 'Low': '7.6', 'Close': '7.9', 'Adj Close': '5.687858', 'Volume': '774057', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'Date': '1/06/2000', 'Open': '7.866666', 'High': '7.866666', 'Low': '7.503333', 'Close': '7.633333', 'Adj Close': '5.495861', 'Volume': '982848', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '2/06/2000', 'Open': '7.694666', 'High': '7.716666', 'Low': '7.516666', 'Close': '7.532', 'Adj Close': '5.422904', 'Volume': '310668', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '5/06/2000', 'Open': '7.569333', 'High': '7.7', 'Low': '7.566666', 'Close': '7.659666', 'Adj Close': '5.514822', 'Volume': '273441', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '6/06/2000', 'Open': '7.656666', 'High': '7.656666', 'Low': '7.583333', 'Close': '7.6', 'Adj Close': '5.471862', 'Volume': '457749', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '7/06/2000', 'Open': '7.633333', 'High': '7.633333', 'Low': '7.316666', 'Close': '7.333333', 'Adj Close': '5.279866', 'Volume': '1278297', 'SENTIMENT': 'NEUTRAL', 'RBA': '6', 'FED': '6.86'}
# {'Date': '8/06/2000', 'Open': '7.333333', 'High': '7.333333', 'Low': '7.333333', 'Close': '7.333333', 'Adj Close': '5.279866', 'Volume': '0', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '9/06/2000', 'Open': '9.166', 'High': '9.83', 'Low': '8.916666', 'Close': '9.583333', 'Adj Close': '6.899827', 'Volume': '3348009', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '12/06/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '13/06/2000', 'Open': '9.333333', 'High': '9.77', 'Low': '9.166666', 'Close': '9.693333', 'Adj Close': '6.979023', 'Volume': '2567925', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '14/06/2000', 'Open': '9.666666', 'High': '9.687333', 'Low': '9.633333', 'Close': '9.687333', 'Adj Close': '6.974704', 'Volume': '1515588', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '15/06/2000', 'Open': '9.733333', 'High': '10.093333', 'Low': '9.733333', 'Close': '10', 'Adj Close': '7.19982', 'Volume': '1963995', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '16/06/2000', 'Open': '10', 'High': '10.5', 'Low': '10', 'Close': '10.133333', 'Adj Close': '7.295815', 'Volume': '1428390', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '19/06/2000', 'Open': '10', 'High': '10.136666', 'Low': '10', 'Close': '10.066666', 'Adj Close': '7.247818', 'Volume': '1012647', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '20/06/2000', 'Open': '10.002', 'High': '10.066666', 'Low': '9.9', 'Close': '10.033333', 'Adj Close': '7.223818', 'Volume': '995220', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '21/06/2000', 'Open': '10.003', 'High': '10.333333', 'Low': '10', 'Close': '10.333333', 'Adj Close': '7.439813', 'Volume': '553188', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '22/06/2000', 'Open': '10.502666', 'High': '11.033333', 'Low': '10.35', 'Close': '10.807666', 'Adj Close': '7.781324', 'Volume': '1567623', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '23/06/2000', 'Open': '10.780666', 'High': '11.203333', 'Low': '10.780666', 'Close': '11.174333', 'Adj Close': '8.045319', 'Volume': '1692561', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '26/06/2000', 'Open': '11.183333', 'High': '11.363333', 'Low': '11.1', 'Close': '11.316666', 'Adj Close': '8.147797', 'Volume': '1478388', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '27/06/2000', 'Open': '11.338', 'High': '11.593333', 'Low': '11.236666', 'Close': '11.298333', 'Adj Close': '8.134596', 'Volume': '2256255', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '28/06/2000', 'Open': '10.988666', 'High': '11', 'Low': '10.6', 'Close': '10.904', 'Adj Close': '7.850684', 'Volume': '2177307', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '29/06/2000', 'Open': '10.887333', 'High': '10.887333', 'Low': '10.5', 'Close': '10.55', 'Adj Close': '7.59581', 'Volume': '811515', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '30/06/2000', 'Open': '10.332333', 'High': '11.011666', 'Low': '10.332333', 'Close': '11.011666', 'Adj Close': '7.928201', 'Volume': '1864875', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'Date': '3/07/2000', 'Open': '10.695', 'High': '11.45', 'Low': '10.695', 'Close': '11.432', 'Adj Close': '8.230832', 'Volume': '1517391', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '4/07/2000', 'Open': '11.316666', 'High': '11.483333', 'Low': '11.083333', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '990279', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '5/07/2000', 'Open': '11.333333', 'High': '11.366666', 'Low': '11.166666', 'Close': '11.3', 'Adj Close': '8.135795', 'Volume': '1069248', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '6/07/2000', 'Open': '11.136666', 'High': '11.15', 'Low': '11.066666', 'Close': '11.106', 'Adj Close': '7.996118', 'Volume': '649389', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '7/07/2000', 'Open': '11.116666', 'High': '11.326666', 'Low': '11.11', 'Close': '11.111666', 'Adj Close': '8.000198', 'Volume': '829698', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '10/07/2000', 'Open': '11.121666', 'High': '11.333333', 'Low': '11.121666', 'Close': '11.3', 'Adj Close': '8.135795', 'Volume': '625728', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '11/07/2000', 'Open': '11.3', 'High': '11.34', 'Low': '11.293333', 'Close': '11.303333', 'Adj Close': '8.138192', 'Volume': '795117', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '12/07/2000', 'Open': '11.239333', 'High': '11.3', 'Low': '11.133333', 'Close': '11.133333', 'Adj Close': '8.015798', 'Volume': '814278', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '13/07/2000', 'Open': '11.135', 'High': '11.266666', 'Low': '11.033333', 'Close': '11.233333', 'Adj Close': '8.087796', 'Volume': '277344', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '14/07/2000', 'Open': '11.190666', 'High': '11.333333', 'Low': '11.190666', 'Close': '11.293333', 'Adj Close': '8.130997', 'Volume': '891420', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '17/07/2000', 'Open': '11.295', 'High': '11.366666', 'Low': '11.166666', 'Close': '11.329333', 'Adj Close': '8.156916', 'Volume': '1259106', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '18/07/2000', 'Open': '11.3', 'High': '11.333333', 'Low': '11.263333', 'Close': '11.302333', 'Adj Close': '8.137476', 'Volume': '688809', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '19/07/2000', 'Open': '11.270333', 'High': '11.433333', 'Low': '11.270333', 'Close': '11.401', 'Adj Close': '8.208515', 'Volume': '1103241', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '20/07/2000', 'Open': '11.301', 'High': '11.5', 'Low': '11.301', 'Close': '11.483666', 'Adj Close': '8.268032', 'Volume': '410355', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '21/07/2000', 'Open': '11.5', 'High': '11.5', 'Low': '11.333333', 'Close': '11.36', 'Adj Close': '8.178996', 'Volume': '790554', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '24/07/2000', 'Open': '11.308666', 'High': '11.366666', 'Low': '11.266666', 'Close': '11.365', 'Adj Close': '8.182593', 'Volume': '830796', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '25/07/2000', 'Open': '11.333333', 'High': '11.43', 'Low': '11.303333', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '487569', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '26/07/2000', 'Open': '11.306666', 'High': '11.396666', 'Low': '11.306666', 'Close': '11.371666', 'Adj Close': '8.187391', 'Volume': '917904', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '27/07/2000', 'Open': '11.383333', 'High': '11.55', 'Low': '11.383333', 'Close': '11.466666', 'Adj Close': '8.255795', 'Volume': '1001859', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '28/07/2000', 'Open': '11.333333', 'High': '11.35', 'Low': '11.316666', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '522087', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '31/07/2000', 'Open': '11.266666', 'High': '11.333333', 'Low': '11.166666', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '1040352', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.99', 'FED': '6.64'}
# {'Date': '1/08/2000', 'Open': '11.333333', 'High': '11.35', 'Low': '11.2', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '965700', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '2/08/2000', 'Open': '11.333333', 'High': '11.4', 'Low': '11.3', 'Close': '11.336666', 'Adj Close': '8.162194', 'Volume': '818703', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '3/08/2000', 'Open': '11.4', 'High': '11.4', 'Low': '11.283333', 'Close': '11.306666', 'Adj Close': '8.140594', 'Volume': '1106490', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '4/08/2000', 'Open': '11.333333', 'High': '11.366666', 'Low': '11.313333', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '737526', 'SENTIMENT': 'NEUTRAL', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '7/08/2000', 'Open': '11.333333', 'High': '11.343333', 'Low': '11.316666', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '543000', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '8/08/2000', 'Open': '11.361666', 'High': '11.383333', 'Low': '11.333333', 'Close': '11.339', 'Adj Close': '8.163875', 'Volume': '762471', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '9/08/2000', 'Open': '11.333333', 'High': '11.466666', 'Low': '11.333333', 'Close': '11.466666', 'Adj Close': '8.255795', 'Volume': '475374', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '10/08/2000', 'Open': '11.464666', 'High': '11.496666', 'Low': '11.396666', 'Close': '11.4', 'Adj Close': '8.207792', 'Volume': '610152', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '11/08/2000', 'Open': '11.433333', 'High': '11.433333', 'Low': '11.333333', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '727050', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '14/08/2000', 'Open': '11.333333', 'High': '11.496666', 'Low': '11.333333', 'Close': '11.477666', 'Adj Close': '8.26371', 'Volume': '248688', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '15/08/2000', 'Open': '11.483', 'High': '12.016666', 'Low': '11.483', 'Close': '11.898333', 'Adj Close': '8.566583', 'Volume': '356466', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '16/08/2000', 'Open': '11.886666', 'High': '11.886666', 'Low': '11.516666', 'Close': '11.666666', 'Adj Close': '8.399789', 'Volume': '488625', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '17/08/2000', 'Open': '11.666666', 'High': '11.8', 'Low': '11.65', 'Close': '11.8', 'Adj Close': '8.495788', 'Volume': '808872', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '18/08/2000', 'Open': '11.803', 'High': '12', 'Low': '11.766666', 'Close': '11.783333', 'Adj Close': '8.483788', 'Volume': '538149', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '21/08/2000', 'Open': '11.8', 'High': '11.9', 'Low': '11.73', 'Close': '11.8', 'Adj Close': '8.495788', 'Volume': '397731', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '22/08/2000', 'Open': '11.783333', 'High': '11.9', 'Low': '11.783333', 'Close': '11.83', 'Adj Close': '8.517385', 'Volume': '474306', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '23/08/2000', 'Open': '11.853333', 'High': '11.906666', 'Low': '11.733333', 'Close': '11.846666', 'Adj Close': '8.529387', 'Volume': '1027356', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '24/08/2000', 'Open': '11.869', 'High': '12.333333', 'Low': '11.869', 'Close': '12.2', 'Adj Close': '8.783778', 'Volume': '1238919', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '25/08/2000', 'Open': '12.326666', 'High': '12.35', 'Low': '12.186666', 'Close': '12.333333', 'Adj Close': '8.879778', 'Volume': '671481', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '28/08/2000', 'Open': '12.366666', 'High': '12.433333', 'Low': '12.233333', 'Close': '12.266666', 'Adj Close': '8.831776', 'Volume': '389940', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '29/08/2000', 'Open': '12.333333', 'High': '12.383333', 'Low': '12.27', 'Close': '12.3', 'Adj Close': '8.855778', 'Volume': '573861', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '30/08/2000', 'Open': '12.3', 'High': '12.3', 'Low': '12', 'Close': '12.119333', 'Adj Close': '8.725699', 'Volume': '460311', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '31/08/2000', 'Open': '12.102', 'High': '12.102', 'Low': '11.75', 'Close': '11.842333', 'Adj Close': '8.526266', 'Volume': '710832', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'Date': '1/09/2000', 'Open': '11.852666', 'High': '11.866666', 'Low': '11.636666', 'Close': '11.683333', 'Adj Close': '8.411788', 'Volume': '759840', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '4/09/2000', 'Open': '11.676666', 'High': '11.833333', 'Low': '11.666666', 'Close': '11.698333', 'Adj Close': '8.422588', 'Volume': '1344159', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '5/09/2000', 'Open': '11.7', 'High': '12', 'Low': '11.7', 'Close': '11.994666', 'Adj Close': '8.635939', 'Volume': '255645', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '6/09/2000', 'Open': '11.991', 'High': '11.991', 'Low': '11.75', 'Close': '11.758333', 'Adj Close': '8.465787', 'Volume': '1479120', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '7/09/2000', 'Open': '11.783333', 'High': '11.786666', 'Low': '11.703333', 'Close': '11.766666', 'Adj Close': '8.471786', 'Volume': '547920', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '8/09/2000', 'Open': '11.766666', 'High': '11.916666', 'Low': '11.733333', 'Close': '11.813333', 'Adj Close': '8.505389', 'Volume': '229173', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '11/09/2000', 'Open': '11.829', 'High': '12.083333', 'Low': '11.829', 'Close': '11.933333', 'Adj Close': '8.591784', 'Volume': '808383', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '12/09/2000', 'Open': '11.951666', 'High': '12', 'Low': '11.866666', 'Close': '11.9', 'Adj Close': '8.567786', 'Volume': '486270', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '13/09/2000', 'Open': '11.902666', 'High': '12', 'Low': '11.873333', 'Close': '11.996666', 'Adj Close': '8.637382', 'Volume': '1036476', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '14/09/2000', 'Open': '11.983333', 'High': '12.1', 'Low': '11.966666', 'Close': '12.033333', 'Adj Close': '8.663777', 'Volume': '598035', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '15/09/2000', 'Open': '12.036666', 'High': '12.066666', 'Low': '11.866666', 'Close': '12', 'Adj Close': '8.639781', 'Volume': '723816', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '18/09/2000', 'Open': '11.994333', 'High': '11.994333', 'Low': '11.666666', 'Close': '11.7', 'Adj Close': '8.423787', 'Volume': '475542', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '19/09/2000', 'Open': '11.666666', 'High': '11.666666', 'Low': '11.133333', 'Close': '11.16', 'Adj Close': '8.034996', 'Volume': '1258485', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '20/09/2000', 'Open': '11.113333', 'High': '11.35', 'Low': '11.003333', 'Close': '11.35', 'Adj Close': '8.171793', 'Volume': '1177020', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '21/09/2000', 'Open': '11.35', 'High': '11.633333', 'Low': '11.35', 'Close': '11.59', 'Adj Close': '8.344589', 'Volume': '1342197', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '22/09/2000', 'Open': '11.328', 'High': '11.4', 'Low': '11.173333', 'Close': '11.233333', 'Adj Close': '8.122838', 'Volume': '1181556', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '25/09/2000', 'Open': '11.366666', 'High': '11.466666', 'Low': '11.35', 'Close': '11.433333', 'Adj Close': '8.267456', 'Volume': '649707', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '26/09/2000', 'Open': '11.433333', 'High': '11.45', 'Low': '11.4', 'Close': '11.416666', 'Adj Close': '8.255407', 'Volume': '770097', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '27/09/2000', 'Open': '11.416666', 'High': '11.416666', 'Low': '11.163666', 'Close': '11.163666', 'Adj Close': '8.072463', 'Volume': '327267', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '28/09/2000', 'Open': '11.160333', 'High': '11.160333', 'Low': '10.583333', 'Close': '11', 'Adj Close': '7.954113', 'Volume': '747318', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '29/09/2000', 'Open': '11.02', 'High': '11.57', 'Low': '11.02', 'Close': '11.566666', 'Adj Close': '8.363873', 'Volume': '733767', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'Date': '2/10/2000', 'Open': '11.555666', 'High': '11.566666', 'Low': '11.416666', 'Close': '11.533333', 'Adj Close': '8.33977', 'Volume': '195522', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '3/10/2000', 'Open': '11.5', 'High': '11.506666', 'Low': '11.066666', 'Close': '11.164333', 'Adj Close': '8.072946', 'Volume': '1259451', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '4/10/2000', 'Open': '11.166666', 'High': '11.166666', 'Low': '11.066666', 'Close': '11.166666', 'Adj Close': '8.074632', 'Volume': '532506', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '5/10/2000', 'Open': '11.137666', 'High': '11.3', 'Low': '11.116666', 'Close': '11.247333', 'Adj Close': '8.13296', 'Volume': '646614', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '6/10/2000', 'Open': '11.3', 'High': '11.553333', 'Low': '11.3', 'Close': '11.553333', 'Adj Close': '8.354233', 'Volume': '479142', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '9/10/2000', 'Open': '11.530333', 'High': '11.55', 'Low': '11.4', 'Close': '11.5', 'Adj Close': '8.315666', 'Volume': '819786', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '10/10/2000', 'Open': '11.493333', 'High': '11.53', 'Low': '11.183333', 'Close': '11.186666', 'Adj Close': '8.089093', 'Volume': '768651', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '11/10/2000', 'Open': '11.133333', 'High': '11.133333', 'Low': '10.6', 'Close': '10.716666', 'Adj Close': '7.749235', 'Volume': '2511813', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '12/10/2000', 'Open': '10.716666', 'High': '11', 'Low': '10.543333', 'Close': '10.766666', 'Adj Close': '7.785393', 'Volume': '1574004', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '13/10/2000', 'Open': '10.766666', 'High': '11', 'Low': '10.766666', 'Close': '10.95', 'Adj Close': '7.91796', 'Volume': '733785', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '16/10/2000', 'Open': '11', 'High': '11.366666', 'Low': '11', 'Close': '11.366666', 'Adj Close': '8.219254', 'Volume': '543675', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '17/10/2000', 'Open': '11.375', 'High': '11.666666', 'Low': '11.37', 'Close': '11.633333', 'Adj Close': '8.412081', 'Volume': '781017', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '18/10/2000', 'Open': '11.606666', 'High': '11.606666', 'Low': '11.433333', 'Close': '11.510666', 'Adj Close': '8.323376', 'Volume': '393102', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '19/10/2000', 'Open': '11.421666', 'High': '11.606666', 'Low': '11.421666', 'Close': '11.53', 'Adj Close': '8.337359', 'Volume': '782061', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '20/10/2000', 'Open': '11.533', 'High': '11.826666', 'Low': '11.533', 'Close': '11.716666', 'Adj Close': '8.47234', 'Volume': '623145', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '23/10/2000', 'Open': '11.700333', 'High': '12', 'Low': '11.700333', 'Close': '11.766666', 'Adj Close': '8.508492', 'Volume': '324789', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '24/10/2000', 'Open': '11.733333', 'High': '11.733333', 'Low': '11.6', 'Close': '11.633333', 'Adj Close': '8.412081', 'Volume': '468846', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '25/10/2000', 'Open': '11.598666', 'High': '11.696666', 'Low': '11.598666', 'Close': '11.666666', 'Adj Close': '8.436182', 'Volume': '716703', 'SENTIMENT': 'NEUTRAL', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '26/10/2000', 'Open': '11.633333', 'High': '11.716666', 'Low': '11.516666', 'Close': '11.666666', 'Adj Close': '8.436182', 'Volume': '579906', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '27/10/2000', 'Open': '11.666666', 'High': '11.816666', 'Low': '11.6', 'Close': '11.6', 'Adj Close': '8.387976', 'Volume': '379209', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '30/10/2000', 'Open': '11.7', 'High': '11.733333', 'Low': '11.5', 'Close': '11.5', 'Adj Close': '8.315666', 'Volume': '252162', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '31/10/2000', 'Open': '11.516666', 'High': '11.52', 'Low': '11.416666', 'Close': '11.439333', 'Adj Close': '8.271794', 'Volume': '420951', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'Date': '1/11/2000', 'Open': '11.502', 'High': '11.7', 'Low': '11.5', 'Close': '11.7', 'Adj Close': '8.460286', 'Volume': '413787', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '2/11/2000', 'Open': '11.666666', 'High': '12.166666', 'Low': '11.666666', 'Close': '12.166666', 'Adj Close': '8.797735', 'Volume': '686814', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '3/11/2000', 'Open': '12.149666', 'High': '12.176666', 'Low': '12.046666', 'Close': '12.15', 'Adj Close': '8.785683', 'Volume': '373854', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '6/11/2000', 'Open': '11.997333', 'High': '12.058666', 'Low': '11.816666', 'Close': '12.058666', 'Adj Close': '8.719639', 'Volume': '220335', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '7/11/2000', 'Open': '12.09', 'High': '12.116666', 'Low': '11.953333', 'Close': '11.976666', 'Adj Close': '8.660345', 'Volume': '439485', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '8/11/2000', 'Open': '11.965', 'High': '11.965', 'Low': '11.623333', 'Close': '11.623333', 'Adj Close': '8.40485', 'Volume': '392682', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '9/11/2000', 'Open': '11.597', 'High': '11.833333', 'Low': '11.566666', 'Close': '11.733333', 'Adj Close': '8.484391', 'Volume': '322746', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '10/11/2000', 'Open': '11.663666', 'High': '12', 'Low': '11.65', 'Close': '12', 'Adj Close': '8.677216', 'Volume': '249222', 'SENTIMENT': 'NEUTRAL', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '13/11/2000', 'Open': '11.574333', 'High': '12.003333', 'Low': '11.574333', 'Close': '12', 'Adj Close': '8.677216', 'Volume': '538443', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '14/11/2000', 'Open': '11.996666', 'High': '12.05', 'Low': '11.796666', 'Close': '12.033333', 'Adj Close': '8.701315', 'Volume': '346335', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '15/11/2000', 'Open': '12.033333', 'High': '12.28', 'Low': '12.033333', 'Close': '12.193333', 'Adj Close': '8.817017', 'Volume': '730338', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '16/11/2000', 'Open': '12.183333', 'High': '12.233333', 'Low': '11.866666', 'Close': '11.893666', 'Adj Close': '8.600328', 'Volume': '381774', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '17/11/2000', 'Open': '11.986666', 'High': '12.016666', 'Low': '11.833333', 'Close': '11.970666', 'Adj Close': '8.656003', 'Volume': '203301', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '20/11/2000', 'Open': '11.98', 'High': '12.283333', 'Low': '11.963333', 'Close': '12.283333', 'Adj Close': '8.882095', 'Volume': '385788', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '21/11/2000', 'Open': '12.147', 'High': '12.366666', 'Low': '12.147', 'Close': '12.25', 'Adj Close': '8.857993', 'Volume': '383058', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '22/11/2000', 'Open': '12.266666', 'High': '12.5', 'Low': '12.196666', 'Close': '12.5', 'Adj Close': '9.038768', 'Volume': '190167', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '23/11/2000', 'Open': '12.467', 'High': '12.467', 'Low': '11.933333', 'Close': '12.25', 'Adj Close': '8.857993', 'Volume': '165723', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '24/11/2000', 'Open': '12.26', 'High': '12.7', 'Low': '12.253333', 'Close': '12.433333', 'Adj Close': '8.990561', 'Volume': '516663', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '27/11/2000', 'Open': '12.333333', 'High': '12.333333', 'Low': '11.966666', 'Close': '12.183333', 'Adj Close': '8.809782', 'Volume': '374136', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '28/11/2000', 'Open': '12.2', 'High': '12.2', 'Low': '11.866666', 'Close': '12.142333', 'Adj Close': '8.780136', 'Volume': '608271', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '29/11/2000', 'Open': '12.166666', 'High': '12.2', 'Low': '11.966666', 'Close': '12.196', 'Adj Close': '8.818945', 'Volume': '93138', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '30/11/2000', 'Open': '12.219', 'High': '12.283333', 'Low': '11.833333', 'Close': '11.992666', 'Adj Close': '8.671916', 'Volume': '615840', 'SENTIMENT': 'POSITIVE', 'RBA': '6.22', 'FED': '6.62'}
# {'Date': '1/12/2000', 'Open': '11.958', 'High': '12.266666', 'Low': '11.833333', 'Close': '12.183333', 'Adj Close': '8.809782', 'Volume': '308619', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '5.41'}
# {'Date': '4/12/2000', 'Open': '12.1', 'High': '12.116666', 'Low': '12', 'Close': '12.033333', 'Adj Close': '8.701315', 'Volume': '285060', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '5.41'}
# {'Date': '5/12/2000', 'Open': '12.050666', 'High': '12.533333', 'Low': '12.050666', 'Close': '12.517666', 'Adj Close': '9.051542', 'Volume': '590742', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '5.41'}
# ...
# {'Date': '30/12/2021', 'Open': '295.48999', 'High': '295.48999', 'Low': '292.019989', 'Close': '292.5', 'Adj Close': '290.888702', 'Volume': '363625', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.04', 'FED': '0.07'}
# {'Date': '31/12/2021', 'Open': '291.200012', 'High': '292.929993', 'Low': '290.230011', 'Close': '290.720001', 'Adj Close': '289.1185', 'Volume': '364694', 'SENTIMENT': 'POSITIVE', 'RBA': '0.04', 'FED': '0.07'}
# {'Date': '4/01/2022', 'Open': '288.559998', 'High': '296.230011', 'Low': '288.5', 'Close': '295.98999', 'Adj Close': '294.359467', 'Volume': '587683', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '5/01/2022', 'Open': '294.970001', 'High': '295.600006', 'Low': '290.399994', 'Close': '290.600006', 'Adj Close': '288.999176', 'Volume': '722951', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '6/01/2022', 'Open': '286', 'High': '289.049988', 'Low': '279.200012', 'Close': '280', 'Adj Close': '278.45755', 'Volume': '1060940', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '7/01/2022', 'Open': '283.709991', 'High': '285.130005', 'Low': '281.230011', 'Close': '282.399994', 'Adj Close': '280.84433', 'Volume': '600319', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '10/01/2022', 'Open': '281', 'High': '282.25', 'Low': '277.890015', 'Close': '280', 'Adj Close': '278.45755', 'Volume': '422980', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '11/01/2022', 'Open': '282.399994', 'High': '282.399994', 'Low': '277.940002', 'Close': '277.940002', 'Adj Close': '276.408905', 'Volume': '731127', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '12/01/2022', 'Open': '280.890015', 'High': '284.769989', 'Low': '279.640015', 'Close': '283.130005', 'Adj Close': '281.570313', 'Volume': '816567', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '13/01/2022', 'Open': '284.390015', 'High': '284.799988', 'Low': '280.519989', 'Close': '281.700012', 'Adj Close': '280.148193', 'Volume': '504025', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '14/01/2022', 'Open': '280', 'High': '281', 'Low': '275.100006', 'Close': '276', 'Adj Close': '274.479584', 'Volume': '737400', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '17/01/2022', 'Open': '279.589996', 'High': '279.779999', 'Low': '276.630005', 'Close': '278.100006', 'Adj Close': '276.568024', 'Volume': '504295', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '18/01/2022', 'Open': '278', 'High': '279.179993', 'Low': '273.720001', 'Close': '273.720001', 'Adj Close': '272.212158', 'Volume': '595357', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '19/01/2022', 'Open': '271.790009', 'High': '273.459991', 'Low': '270.049988', 'Close': '270.399994', 'Adj Close': '268.910431', 'Volume': '951762', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '20/01/2022', 'Open': '273.160004', 'High': '274.619995', 'Low': '268.519989', 'Close': '271.25', 'Adj Close': '269.755768', 'Volume': '925145', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '21/01/2022', 'Open': '268.640015', 'High': '271.679993', 'Low': '263.269989', 'Close': '264.519989', 'Adj Close': '263.062836', 'Volume': '1707384', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '24/01/2022', 'Open': '263.980011', 'High': '266.170013', 'Low': '261.799988', 'Close': '262.570007', 'Adj Close': '261.123596', 'Volume': '718907', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '25/01/2022', 'Open': '261.179993', 'High': '262.399994', 'Low': '255.600006', 'Close': '258.350006', 'Adj Close': '256.926819', 'Volume': '1556357', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '27/01/2022', 'Open': '260.190002', 'High': '262.26001', 'Low': '245.330002', 'Close': '249.429993', 'Adj Close': '248.055954', 'Volume': '1741008', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '28/01/2022', 'Open': '254.949997', 'High': '258.73999', 'Low': '251.729996', 'Close': '257.51001', 'Adj Close': '256.091461', 'Volume': '3996379', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '31/01/2022', 'Open': '258.01001', 'High': '261.519989', 'Low': '255.5', 'Close': '260.350006', 'Adj Close': '258.915802', 'Volume': '1048060', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '1/02/2022', 'Open': '262.880005', 'High': '264', 'Low': '258.959991', 'Close': '261.549988', 'Adj Close': '260.109192', 'Volume': '693901', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '2/02/2022', 'Open': '263.850006', 'High': '264.26001', 'Low': '259.649994', 'Close': '262.420013', 'Adj Close': '260.974426', 'Volume': '574148', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '3/02/2022', 'Open': '257.769989', 'High': '260.269989', 'Low': '255.5', 'Close': '257.459991', 'Adj Close': '256.041718', 'Volume': '818830', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '4/02/2022', 'Open': '257.450012', 'High': '260.839996', 'Low': '255.660004', 'Close': '258.790009', 'Adj Close': '257.36441', 'Volume': '783457', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '7/02/2022', 'Open': '255.699997', 'High': '257.649994', 'Low': '254.199997', 'Close': '254.610001', 'Adj Close': '253.207428', 'Volume': '684663', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '8/02/2022', 'Open': '255', 'High': '259.410004', 'Low': '255', 'Close': '256.980011', 'Adj Close': '255.564377', 'Volume': '580276', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '9/02/2022', 'Open': '256.019989', 'High': '258.015015', 'Low': '251.5', 'Close': '255.610001', 'Adj Close': '254.20192', 'Volume': '1073196', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '10/02/2022', 'Open': '257.899994', 'High': '257.98999', 'Low': '252.880005', 'Close': '253.710007', 'Adj Close': '252.312393', 'Volume': '1018922', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '11/02/2022', 'Open': '250', 'High': '250.720001', 'Low': '247.5', 'Close': '248.5', 'Adj Close': '247.131088', 'Volume': '1403507', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '14/02/2022', 'Open': '246.509995', 'High': '246.899994', 'Low': '242.589996', 'Close': '243.559998', 'Adj Close': '242.218292', 'Volume': '1070030', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '15/02/2022', 'Open': '241.800003', 'High': '244.300003', 'Low': '240.100006', 'Close': '243', 'Adj Close': '241.661377', 'Volume': '1291429', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '16/02/2022', 'Open': '262.399994', 'High': '264.070007', 'Low': '256.609985', 'Close': '263.690002', 'Adj Close': '262.237396', 'Volume': '2334138', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '17/02/2022', 'Open': '276.869995', 'High': '280', 'Low': '270.440002', 'Close': '277', 'Adj Close': '275.474091', 'Volume': '2491549', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '18/02/2022', 'Open': '272.51001', 'High': '273.970001', 'Low': '265.570007', 'Close': '265.570007', 'Adj Close': '264.107056', 'Volume': '1738836', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '21/02/2022', 'Open': '262.690002', 'High': '264.660004', 'Low': '260.559998', 'Close': '263.540009', 'Adj Close': '262.088226', 'Volume': '577306', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '22/02/2022', 'Open': '262.049988', 'High': '266.980011', 'Low': '260.890015', 'Close': '266.980011', 'Adj Close': '265.509308', 'Volume': '983108', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '23/02/2022', 'Open': '267.049988', 'High': '268.890015', 'Low': '265.089996', 'Close': '268.890015', 'Adj Close': '267.408783', 'Volume': '979362', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '24/02/2022', 'Open': '269.98999', 'High': '269.98999', 'Low': '261.690002', 'Close': '264.790009', 'Adj Close': '263.33136', 'Volume': '1228768', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '25/02/2022', 'Open': '269.019989', 'High': '269.019989', 'Low': '261', 'Close': '261.329987', 'Adj Close': '259.890381', 'Volume': '1067841', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '28/02/2022', 'Open': '258.950012', 'High': '260.869995', 'Low': '256.440002', 'Close': '259.980011', 'Adj Close': '258.547852', 'Volume': '1127660', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '1/03/2022', 'Open': '259.359985', 'High': '264.140015', 'Low': '259.149994', 'Close': '261.100006', 'Adj Close': '259.661682', 'Volume': '951047', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '2/03/2022', 'Open': '255.279999', 'High': '263.5', 'Low': '255.139999', 'Close': '260.75', 'Adj Close': '259.313599', 'Volume': '950661', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '3/03/2022', 'Open': '260', 'High': '263.950012', 'Low': '257.079987', 'Close': '257.5', 'Adj Close': '256.081512', 'Volume': '1220449', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '4/03/2022', 'Open': '257', 'High': '258.529999', 'Low': '253.509995', 'Close': '258.299988', 'Adj Close': '256.877075', 'Volume': '996482', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '7/03/2022', 'Open': '254.509995', 'High': '255.970001', 'Low': '248.970001', 'Close': '249.660004', 'Adj Close': '249.660004', 'Volume': '874716', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '8/03/2022', 'Open': '251.800003', 'High': '259.549988', 'Low': '250.589996', 'Close': '256.649994', 'Adj Close': '256.649994', 'Volume': '911704', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '9/03/2022', 'Open': '258.920013', 'High': '259.140015', 'Low': '253.979996', 'Close': '257', 'Adj Close': '257', 'Volume': '663019', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '10/03/2022', 'Open': '261.269989', 'High': '264.140015', 'Low': '258.079987', 'Close': '263', 'Adj Close': '263', 'Volume': '934165', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '11/03/2022', 'Open': '265', 'High': '265.850006', 'Low': '256.170013', 'Close': '256.529999', 'Adj Close': '256.529999', 'Volume': '1148644', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '14/03/2022', 'Open': '259.619995', 'High': '264.170013', 'Low': '258.600006', 'Close': '263.269989', 'Adj Close': '263.269989', 'Volume': '631755', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '15/03/2022', 'Open': '263.410004', 'High': '265.450012', 'Low': '259.954987', 'Close': '263.769989', 'Adj Close': '263.769989', 'Volume': '505644', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '16/03/2022', 'Open': '267.899994', 'High': '269.98999', 'Low': '266.209991', 'Close': '268.51001', 'Adj Close': '268.51001', 'Volume': '766792', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '17/03/2022', 'Open': '274.73999', 'High': '274.73999', 'Low': '269', 'Close': '270.589996', 'Adj Close': '270.589996', 'Volume': '1079333', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '18/03/2022', 'Open': '271.179993', 'High': '271.51001', 'Low': '267.079987', 'Close': '270.959991', 'Adj Close': '270.959991', 'Volume': '1964122', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '21/03/2022', 'Open': '272.700012', 'High': '273.369995', 'Low': '266.880005', 'Close': '266.970001', 'Adj Close': '266.970001', 'Volume': '559816', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '22/03/2022', 'Open': '268.040009', 'High': '269.959991', 'Low': '265.359985', 'Close': '265.359985', 'Adj Close': '265.359985', 'Volume': '589856', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '23/03/2022', 'Open': '266.299988', 'High': '268.940002', 'Low': '266.119995', 'Close': '267.519989', 'Adj Close': '267.519989', 'Volume': '754641', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '24/03/2022', 'Open': '264.709991', 'High': '267.399994', 'Low': '263.660004', 'Close': '267.399994', 'Adj Close': '267.399994', 'Volume': '718769', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '25/03/2022', 'Open': '266.970001', 'High': '267.890015', 'Low': '264.51001', 'Close': '264.809998', 'Adj Close': '264.809998', 'Volume': '785020', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '28/03/2022', 'Open': '263.5', 'High': '263.970001', 'Low': '260.209991', 'Close': '261.859985', 'Adj Close': '261.859985', 'Volume': '476942', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '29/03/2022', 'Open': '263.779999', 'High': '267.149994', 'Low': '262.5', 'Close': '265.600006', 'Adj Close': '265.600006', 'Volume': '621353', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '30/03/2022', 'Open': '268.529999', 'High': '271.940002', 'Low': '267.820007', 'Close': '270.049988', 'Adj Close': '270.049988', 'Volume': '687777', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '31/03/2022', 'Open': '273.950012', 'High': '273.950012', 'Low': '268.149994', 'Close': '268.149994', 'Adj Close': '268.149994', 'Volume': '1152270', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '1/04/2022', 'Open': '268', 'High': '268.929993', 'Low': '265.809998', 'Close': '266.279999', 'Adj Close': '266.279999', 'Volume': '835555', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '4/04/2022', 'Open': '268', 'High': '270.450012', 'Low': '267.690002', 'Close': '267.690002', 'Adj Close': '267.690002', 'Volume': '469737', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '5/04/2022', 'Open': '270.5', 'High': '271.100006', 'Low': '266.390015', 'Close': '268.529999', 'Adj Close': '268.529999', 'Volume': '546415', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '6/04/2022', 'Open': '268.100006', 'High': '269.459991', 'Low': '266.5', 'Close': '267.540009', 'Adj Close': '267.540009', 'Volume': '517400', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '7/04/2022', 'Open': '267.059998', 'High': '268.329987', 'Low': '266.279999', 'Close': '266.579987', 'Adj Close': '266.579987', 'Volume': '498246', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '8/04/2022', 'Open': '269', 'High': '269', 'Low': '265.380005', 'Close': '265.720001', 'Adj Close': '265.720001', 'Volume': '514648', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '11/04/2022', 'Open': '265.5', 'High': '266.549988', 'Low': '264.709991', 'Close': '265.470001', 'Adj Close': '265.470001', 'Volume': '502366', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '12/04/2022', 'Open': '265', 'High': '265.019989', 'Low': '260.869995', 'Close': '261.970001', 'Adj Close': '261.970001', 'Volume': '566745', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '13/04/2022', 'Open': '262', 'High': '264.109985', 'Low': '262', 'Close': '262.959991', 'Adj Close': '262.959991', 'Volume': '585733', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '14/04/2022', 'Open': '262.959991', 'High': '265.459991', 'Low': '262.049988', 'Close': '264.950012', 'Adj Close': '264.950012', 'Volume': '805253', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '19/04/2022', 'Open': '263', 'High': '264.589996', 'Low': '261.579987', 'Close': '262.350006', 'Adj Close': '262.350006', 'Volume': '700468', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'Date': '20/04/2022', 'Open': '266.100006', 'High': '267.98999', 'Low': '263.700012', 'Close': '264.5', 'Adj Close': '264.5', 'Volume': '857150', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}

# %%
# # query the collection
# csls = db.csl.find()

# # see change in collection
# for csl in csls:
#     print(csl)
# Out:
# {'_id': ObjectId('62653091f0a054097b5be49d'), 'Date': '3/01/2000', 'Open': '7.3', 'High': '7.3', 'Low': '7.3', 'Close': '7.3', 'Adj Close': '5.234562', 'Volume': '0', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be49e'), 'Date': '4/01/2000', 'Open': '7.333333', 'High': '7.333333', 'Low': '7.066666', 'Close': '7.186666', 'Adj Close': '5.153295', 'Volume': '254295', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be49f'), 'Date': '5/01/2000', 'Open': '7', 'High': '7.183333', 'Low': '7', 'Close': '7.155', 'Adj Close': '5.130589', 'Volume': '424941', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a0'), 'Date': '6/01/2000', 'Open': '7.233333', 'High': '7.273333', 'Low': '7', 'Close': '7', 'Adj Close': '5.019443', 'Volume': '348534', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a1'), 'Date': '7/01/2000', 'Open': '7.013', 'High': '7.023333', 'Low': '6.8', 'Close': '6.85', 'Adj Close': '4.911883', 'Volume': '483963', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a2'), 'Date': '10/01/2000', 'Open': '7', 'High': '7.333333', 'Low': '7', 'Close': '7.333333', 'Adj Close': '5.258464', 'Volume': '546525', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a3'), 'Date': '11/01/2000', 'Open': '7.333333', 'High': '7.333333', 'Low': '7.233333', 'Close': '7.316666', 'Adj Close': '5.246511', 'Volume': '870903', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a4'), 'Date': '12/01/2000', 'Open': '7.166666', 'High': '7.4', 'Low': '7.166666', 'Close': '7.4', 'Adj Close': '5.306267', 'Volume': '321720', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a5'), 'Date': '13/01/2000', 'Open': '7.366666', 'High': '7.466666', 'Low': '7.3', 'Close': '7.366666', 'Adj Close': '5.282365', 'Volume': '565902', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a6'), 'Date': '14/01/2000', 'Open': '7.333333', 'High': '7.496666', 'Low': '7.333333', 'Close': '7.486666', 'Adj Close': '5.368413', 'Volume': '551202', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a7'), 'Date': '17/01/2000', 'Open': '7.48', 'High': '7.716666', 'Low': '7.466666', 'Close': '7.566666', 'Adj Close': '5.425777', 'Volume': '1372908', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a8'), 'Date': '18/01/2000', 'Open': '7.566666', 'High': '7.566666', 'Low': '7.43', 'Close': '7.55', 'Adj Close': '5.413829', 'Volume': '514509', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4a9'), 'Date': '19/01/2000', 'Open': '7.533333', 'High': '7.566666', 'Low': '7.42', 'Close': '7.566666', 'Adj Close': '5.425777', 'Volume': '365580', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4aa'), 'Date': '20/01/2000', 'Open': '7.533333', 'High': '7.733333', 'Low': '7.53', 'Close': '7.716666', 'Adj Close': '5.533338', 'Volume': '1940439', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4ab'), 'Date': '21/01/2000', 'Open': '7.583333', 'High': '7.683333', 'Low': '7.58', 'Close': '7.583333', 'Adj Close': '5.43773', 'Volume': '407316', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4ac'), 'Date': '24/01/2000', 'Open': '7.533333', 'High': '7.593333', 'Low': '7.516666', 'Close': '7.533333', 'Adj Close': '5.401875', 'Volume': '213306', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4ad'), 'Date': '25/01/2000', 'Open': '7.529', 'High': '7.529', 'Low': '7.466666', 'Close': '7.516333', 'Adj Close': '5.389686', 'Volume': '1039110', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4ae'), 'Date': '26/01/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4af'), 'Date': '27/01/2000', 'Open': '7.534', 'High': '7.8', 'Low': '7.533333', 'Close': '7.733333', 'Adj Close': '5.545289', 'Volume': '929907', 'SENTIMENT': 'NEGATIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4b0'), 'Date': '28/01/2000', 'Open': '7.720666', 'High': '7.720666', 'Low': '7.666666', 'Close': '7.666666', 'Adj Close': '5.497485', 'Volume': '280431', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4b1'), 'Date': '31/01/2000', 'Open': '7.655333', 'High': '7.733333', 'Low': '7.55', 'Close': '7.697666', 'Adj Close': '5.519713', 'Volume': '778572', 'SENTIMENT': 'POSITIVE', 'RBA': '4.98', 'FED': '5.87'}
# {'_id': ObjectId('62653091f0a054097b5be4b2'), 'Date': '1/02/2000', 'Open': '7.7', 'High': '7.766666', 'Low': '7.7', 'Close': '7.733333', 'Adj Close': '5.545289', 'Volume': '527550', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4b3'), 'Date': '2/02/2000', 'Open': '7.783333', 'High': '7.783333', 'Low': '7.633333', 'Close': '7.75', 'Adj Close': '5.55724', 'Volume': '218361', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4b4'), 'Date': '3/02/2000', 'Open': '7.669', 'High': '7.8', 'Low': '7.669', 'Close': '7.763333', 'Adj Close': '5.566802', 'Volume': '369984', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4b5'), 'Date': '4/02/2000', 'Open': '7.759666', 'High': '7.85', 'Low': '7.726666', 'Close': '7.766666', 'Adj Close': '5.569191', 'Volume': '474762', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4b6'), 'Date': '7/02/2000', 'Open': '7.732', 'High': '7.816666', 'Low': '7.732', 'Close': '7.783333', 'Adj Close': '5.581141', 'Volume': '360501', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4b7'), 'Date': '8/02/2000', 'Open': '7.735333', 'High': '7.75', 'Low': '7.533333', 'Close': '7.566666', 'Adj Close': '5.425777', 'Volume': '495267', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4b8'), 'Date': '9/02/2000', 'Open': '7.533', 'High': '7.666666', 'Low': '7.533', 'Close': '7.616666', 'Adj Close': '5.461631', 'Volume': '465558', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4b9'), 'Date': '10/02/2000', 'Open': '7.616666', 'High': '7.683333', 'Low': '7.583333', 'Close': '7.666666', 'Adj Close': '5.497485', 'Volume': '2397987', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4ba'), 'Date': '11/02/2000', 'Open': '7.666666', 'High': '7.666666', 'Low': '7.38', 'Close': '7.433333', 'Adj Close': '5.330169', 'Volume': '1005972', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4bb'), 'Date': '14/02/2000', 'Open': '7.410333', 'High': '7.410333', 'Low': '7.363333', 'Close': '7.38', 'Adj Close': '5.291926', 'Volume': '469875', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4bc'), 'Date': '15/02/2000', 'Open': '7.346333', 'High': '7.366666', 'Low': '7.3', 'Close': '7.366666', 'Adj Close': '5.282365', 'Volume': '1430886', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4bd'), 'Date': '16/02/2000', 'Open': '7.434333', 'High': '7.434333', 'Low': '7.193333', 'Close': '7.253333', 'Adj Close': '5.201099', 'Volume': '618939', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4be'), 'Date': '17/02/2000', 'Open': '7.166666', 'High': '7.166666', 'Low': '7', 'Close': '7.031333', 'Adj Close': '5.041911', 'Volume': '764163', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4bf'), 'Date': '18/02/2000', 'Open': '7.029666', 'High': '7.033333', 'Low': '6.833333', 'Close': '6.903', 'Adj Close': '4.949886', 'Volume': '672681', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4c0'), 'Date': '21/02/2000', 'Open': '6.668666', 'High': '6.95', 'Low': '6.668666', 'Close': '6.916666', 'Adj Close': '4.959687', 'Volume': '320697', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4c1'), 'Date': '22/02/2000', 'Open': '6.913666', 'High': '6.916666', 'Low': '6.866666', 'Close': '6.9', 'Adj Close': '4.947737', 'Volume': '582369', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4c2'), 'Date': '23/02/2000', 'Open': '6.9', 'High': '7.1', 'Low': '6.883333', 'Close': '6.9', 'Adj Close': '4.947737', 'Volume': '228966', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4c3'), 'Date': '24/02/2000', 'Open': '6.9', 'High': '7.116666', 'Low': '6.9', 'Close': '7.05', 'Adj Close': '5.055296', 'Volume': '983379', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4c4'), 'Date': '25/02/2000', 'Open': '7.096666', 'High': '7.096666', 'Low': '6.966666', 'Close': '7.016666', 'Adj Close': '5.031394', 'Volume': '291414', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4c5'), 'Date': '28/02/2000', 'Open': '6.9', 'High': '7.083333', 'Low': '6.9', 'Close': '7.066666', 'Adj Close': '5.067247', 'Volume': '573717', 'SENTIMENT': 'POSITIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4c6'), 'Date': '29/02/2000', 'Open': '7.086666', 'High': '7.266666', 'Low': '7.086666', 'Close': '7.266666', 'Adj Close': '5.210659', 'Volume': '799758', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.46', 'FED': '5.85'}
# {'_id': ObjectId('62653091f0a054097b5be4c7'), 'Date': '1/03/2000', 'Open': '7.236', 'High': '7.283333', 'Low': '7.166666', 'Close': '7.239666', 'Adj Close': '5.191299', 'Volume': '219144', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4c8'), 'Date': '2/03/2000', 'Open': '7.266666', 'High': '7.266666', 'Low': '7', 'Close': '7.066666', 'Adj Close': '5.067247', 'Volume': '163251', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4c9'), 'Date': '3/03/2000', 'Open': '6.833333', 'High': '6.833333', 'Low': '6.5', 'Close': '6.778666', 'Adj Close': '4.860732', 'Volume': '754611', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4ca'), 'Date': '6/03/2000', 'Open': '6.902666', 'High': '7.066666', 'Low': '6.866666', 'Close': '6.966666', 'Adj Close': '4.995541', 'Volume': '1271727', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4cb'), 'Date': '7/03/2000', 'Open': '6.921', 'High': '7.066666', 'Low': '6.9', 'Close': '7', 'Adj Close': '5.019443', 'Volume': '673557', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4cc'), 'Date': '8/03/2000', 'Open': '6.933333', 'High': '6.983333', 'Low': '6.866666', 'Close': '6.9', 'Adj Close': '4.947737', 'Volume': '137508', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4cd'), 'Date': '9/03/2000', 'Open': '6.916666', 'High': '7.266666', 'Low': '6.916666', 'Close': '6.916666', 'Adj Close': '4.959687', 'Volume': '544968', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4ce'), 'Date': '10/03/2000', 'Open': '7.018333', 'High': '7.21', 'Low': '7.018333', 'Close': '7.167333', 'Adj Close': '5.139433', 'Volume': '542694', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4cf'), 'Date': '13/03/2000', 'Open': '7.2', 'High': '7.333333', 'Low': '7.2', 'Close': '7.233333', 'Adj Close': '5.186757', 'Volume': '484104', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d0'), 'Date': '14/03/2000', 'Open': '7.166666', 'High': '7.283333', 'Low': '7.166666', 'Close': '7.233333', 'Adj Close': '5.186757', 'Volume': '306072', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d1'), 'Date': '15/03/2000', 'Open': '7.166666', 'High': '7.3', 'Low': '7.066666', 'Close': '7.233333', 'Adj Close': '5.186757', 'Volume': '346368', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d2'), 'Date': '16/03/2000', 'Open': '7.236333', 'High': '7.596666', 'Low': '7.236333', 'Close': '7.366666', 'Adj Close': '5.282365', 'Volume': '1253349', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d3'), 'Date': '17/03/2000', 'Open': '7.388', 'High': '7.433333', 'Low': '7.323333', 'Close': '7.35', 'Adj Close': '5.270415', 'Volume': '472059', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d4'), 'Date': '20/03/2000', 'Open': '7.341', 'High': '7.374', 'Low': '7.3', 'Close': '7.374', 'Adj Close': '5.287624', 'Volume': '414312', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d5'), 'Date': '21/03/2000', 'Open': '7.334', 'High': '7.433333', 'Low': '7.263333', 'Close': '7.433333', 'Adj Close': '5.330169', 'Volume': '311436', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d6'), 'Date': '22/03/2000', 'Open': '7.437666', 'High': '7.583333', 'Low': '7.433333', 'Close': '7.466666', 'Adj Close': '5.354072', 'Volume': '552117', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d7'), 'Date': '23/03/2000', 'Open': '7.366666', 'High': '7.4', 'Low': '7.333333', 'Close': '7.4', 'Adj Close': '5.306267', 'Volume': '327612', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d8'), 'Date': '24/03/2000', 'Open': '7.4', 'High': '7.4', 'Low': '7.216666', 'Close': '7.333333', 'Adj Close': '5.258464', 'Volume': '222291', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4d9'), 'Date': '27/03/2000', 'Open': '7.333333', 'High': '7.5', 'Low': '7.333333', 'Close': '7.4', 'Adj Close': '5.306267', 'Volume': '2543211', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4da'), 'Date': '28/03/2000', 'Open': '7.433333', 'High': '7.5', 'Low': '7.383333', 'Close': '7.402333', 'Adj Close': '5.307941', 'Volume': '259686', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4db'), 'Date': '29/03/2000', 'Open': '7.35', 'High': '7.433333', 'Low': '7.233333', 'Close': '7.25', 'Adj Close': '5.198709', 'Volume': '224685', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4dc'), 'Date': '30/03/2000', 'Open': '7.31', 'High': '7.31', 'Low': '6.965', 'Close': '6.965', 'Adj Close': '4.994346', 'Volume': '511386', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4dd'), 'Date': '31/03/2000', 'Open': '6.833333', 'High': '6.9', 'Low': '6.666666', 'Close': '6.833333', 'Adj Close': '4.899931', 'Volume': '587913', 'SENTIMENT': 'POSITIVE', 'RBA': '5.49', 'FED': '6.17'}
# {'_id': ObjectId('62653091f0a054097b5be4de'), 'Date': '3/04/2000', 'Open': '6.821333', 'High': '7.133333', 'Low': '6.803333', 'Close': '7.1', 'Adj Close': '5.09115', 'Volume': '544389', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4df'), 'Date': '4/04/2000', 'Open': '7.1', 'High': '7.1', 'Low': '6.663333', 'Close': '6.731666', 'Adj Close': '4.82703', 'Volume': '766302', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e0'), 'Date': '5/04/2000', 'Open': '6.733333', 'High': '6.733333', 'Low': '6.556666', 'Close': '6.578333', 'Adj Close': '4.717082', 'Volume': '690708', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e1'), 'Date': '6/04/2000', 'Open': '6.666666', 'High': '6.666666', 'Low': '6.566666', 'Close': '6.567333', 'Adj Close': '4.728361', 'Volume': '1601097', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e2'), 'Date': '7/04/2000', 'Open': '6.6', 'High': '6.733333', 'Low': '6.6', 'Close': '6.7', 'Adj Close': '4.823878', 'Volume': '844500', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e3'), 'Date': '10/04/2000', 'Open': '6.733333', 'High': '6.766666', 'Low': '6.683333', 'Close': '6.766666', 'Adj Close': '4.871877', 'Volume': '1203087', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e4'), 'Date': '11/04/2000', 'Open': '6.75', 'High': '6.786666', 'Low': '6.666666', 'Close': '6.75', 'Adj Close': '4.859879', 'Volume': '702621', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e5'), 'Date': '12/04/2000', 'Open': '6.75', 'High': '7.033333', 'Low': '6.75', 'Close': '7.033333', 'Adj Close': '5.063872', 'Volume': '873501', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e6'), 'Date': '13/04/2000', 'Open': '7.03', 'High': '7.03', 'Low': '6.79', 'Close': '6.9', 'Adj Close': '4.967873', 'Volume': '333651', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e7'), 'Date': '14/04/2000', 'Open': '6.866666', 'High': '7', 'Low': '6.866666', 'Close': '6.973333', 'Adj Close': '5.020672', 'Volume': '187020', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e8'), 'Date': '17/04/2000', 'Open': '6.483', 'High': '6.666666', 'Low': '6.433333', 'Close': '6.636666', 'Adj Close': '4.778279', 'Volume': '901707', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4e9'), 'Date': '18/04/2000', 'Open': '6.833333', 'High': '6.9', 'Low': '6.766666', 'Close': '6.816666', 'Adj Close': '4.907876', 'Volume': '1093224', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4ea'), 'Date': '19/04/2000', 'Open': '6.829666', 'High': '6.833333', 'Low': '6.773333', 'Close': '6.8', 'Adj Close': '4.895877', 'Volume': '902730', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4eb'), 'Date': '20/04/2000', 'Open': '6.8', 'High': '6.833333', 'Low': '6.733333', 'Close': '6.8', 'Adj Close': '4.895877', 'Volume': '740607', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4ec'), 'Date': '21/04/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4ed'), 'Date': '24/04/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4ee'), 'Date': '25/04/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4ef'), 'Date': '26/04/2000', 'Open': '6.703333', 'High': '6.916666', 'Low': '6.703333', 'Close': '6.85', 'Adj Close': '4.931876', 'Volume': '149985', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4f0'), 'Date': '27/04/2000', 'Open': '6.85', 'High': '6.85', 'Low': '6.75', 'Close': '6.783333', 'Adj Close': '4.883877', 'Volume': '940434', 'SENTIMENT': 'POSITIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4f1'), 'Date': '28/04/2000', 'Open': '6.766666', 'High': '6.883333', 'Low': '6.633333', 'Close': '6.866666', 'Adj Close': '4.943877', 'Volume': '349632', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.72', 'FED': '6.06'}
# {'_id': ObjectId('62653091f0a054097b5be4f2'), 'Date': '1/05/2000', 'Open': '6.868666', 'High': '6.9', 'Low': '6.816666', 'Close': '6.816666', 'Adj Close': '4.907876', 'Volume': '249135', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4f3'), 'Date': '2/05/2000', 'Open': '6.83', 'High': '7', 'Low': '6.83', 'Close': '7', 'Adj Close': '5.039874', 'Volume': '171507', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4f4'), 'Date': '3/05/2000', 'Open': '7.001', 'High': '7.066666', 'Low': '6.906666', 'Close': '7.016666', 'Adj Close': '5.051873', 'Volume': '257940', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4f5'), 'Date': '4/05/2000', 'Open': '6.993666', 'High': '6.993666', 'Low': '6.866666', 'Close': '6.866666', 'Adj Close': '4.943877', 'Volume': '57879', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4f6'), 'Date': '5/05/2000', 'Open': '6.817', 'High': '7', 'Low': '6.817', 'Close': '7', 'Adj Close': '5.039874', 'Volume': '334863', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4f7'), 'Date': '8/05/2000', 'Open': '7.008', 'High': '7.166666', 'Low': '6.866666', 'Close': '7', 'Adj Close': '5.039874', 'Volume': '305301', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4f8'), 'Date': '9/05/2000', 'Open': '7', 'High': '7.1', 'Low': '7', 'Close': '7.02', 'Adj Close': '5.054274', 'Volume': '195366', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4f9'), 'Date': '10/05/2000', 'Open': '7', 'High': '7.03', 'Low': '6.9', 'Close': '7', 'Adj Close': '5.039874', 'Volume': '211260', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4fa'), 'Date': '11/05/2000', 'Open': '6.922666', 'High': '6.922666', 'Low': '6.666666', 'Close': '6.8', 'Adj Close': '4.895877', 'Volume': '352203', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4fb'), 'Date': '12/05/2000', 'Open': '6.833333', 'High': '6.866666', 'Low': '6.833333', 'Close': '6.86', 'Adj Close': '4.939076', 'Volume': '271482', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4fc'), 'Date': '15/05/2000', 'Open': '6.833333', 'High': '6.833333', 'Low': '6.733333', 'Close': '6.733333', 'Adj Close': '4.847879', 'Volume': '1288014', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4fd'), 'Date': '16/05/2000', 'Open': '6.75', 'High': '6.75', 'Low': '6.65', 'Close': '6.672333', 'Adj Close': '4.803959', 'Volume': '265869', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4fe'), 'Date': '17/05/2000', 'Open': '6.697333', 'High': '6.783333', 'Low': '6.696666', 'Close': '6.766666', 'Adj Close': '4.871877', 'Volume': '376725', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be4ff'), 'Date': '18/05/2000', 'Open': '6.75', 'High': '6.8', 'Low': '6.7', 'Close': '6.766666', 'Adj Close': '4.871877', 'Volume': '423822', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be500'), 'Date': '19/05/2000', 'Open': '6.764333', 'High': '6.766666', 'Low': '6.616666', 'Close': '6.693333', 'Adj Close': '4.819079', 'Volume': '186585', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be501'), 'Date': '22/05/2000', 'Open': '6.694', 'High': '6.694', 'Low': '6.623333', 'Close': '6.683333', 'Adj Close': '4.811879', 'Volume': '279186', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be502'), 'Date': '23/05/2000', 'Open': '6.666666', 'High': '6.7', 'Low': '6.66', 'Close': '6.666666', 'Adj Close': '4.799879', 'Volume': '314550', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be503'), 'Date': '24/05/2000', 'Open': '6.65', 'High': '6.733333', 'Low': '6.633333', 'Close': '6.733333', 'Adj Close': '4.847879', 'Volume': '1207137', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be504'), 'Date': '25/05/2000', 'Open': '6.766666', 'High': '7.05', 'Low': '6.733333', 'Close': '7.033333', 'Adj Close': '5.063872', 'Volume': '861078', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be505'), 'Date': '26/05/2000', 'Open': '6.866666', 'High': '7.266666', 'Low': '6.866666', 'Close': '7.213', 'Adj Close': '5.193228', 'Volume': '1058268', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be506'), 'Date': '29/05/2000', 'Open': '7.183333', 'High': '7.416666', 'Low': '7.183333', 'Close': '7.37', 'Adj Close': '5.306265', 'Volume': '254409', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be507'), 'Date': '30/05/2000', 'Open': '7.402333', 'High': '7.533333', 'Low': '7.4', 'Close': '7.533333', 'Adj Close': '5.423863', 'Volume': '300171', 'SENTIMENT': 'POSITIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be508'), 'Date': '31/05/2000', 'Open': '7.603333', 'High': '7.9', 'Low': '7.6', 'Close': '7.9', 'Adj Close': '5.687858', 'Volume': '774057', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.98', 'FED': '6.83'}
# {'_id': ObjectId('62653091f0a054097b5be509'), 'Date': '1/06/2000', 'Open': '7.866666', 'High': '7.866666', 'Low': '7.503333', 'Close': '7.633333', 'Adj Close': '5.495861', 'Volume': '982848', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be50a'), 'Date': '2/06/2000', 'Open': '7.694666', 'High': '7.716666', 'Low': '7.516666', 'Close': '7.532', 'Adj Close': '5.422904', 'Volume': '310668', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be50b'), 'Date': '5/06/2000', 'Open': '7.569333', 'High': '7.7', 'Low': '7.566666', 'Close': '7.659666', 'Adj Close': '5.514822', 'Volume': '273441', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be50c'), 'Date': '6/06/2000', 'Open': '7.656666', 'High': '7.656666', 'Low': '7.583333', 'Close': '7.6', 'Adj Close': '5.471862', 'Volume': '457749', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be50d'), 'Date': '7/06/2000', 'Open': '7.633333', 'High': '7.633333', 'Low': '7.316666', 'Close': '7.333333', 'Adj Close': '5.279866', 'Volume': '1278297', 'SENTIMENT': 'NEUTRAL', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be50e'), 'Date': '8/06/2000', 'Open': '7.333333', 'High': '7.333333', 'Low': '7.333333', 'Close': '7.333333', 'Adj Close': '5.279866', 'Volume': '0', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be50f'), 'Date': '9/06/2000', 'Open': '9.166', 'High': '9.83', 'Low': '8.916666', 'Close': '9.583333', 'Adj Close': '6.899827', 'Volume': '3348009', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be510'), 'Date': '12/06/2000', 'Open': 'null', 'High': 'null', 'Low': 'null', 'Close': 'null', 'Adj Close': 'null', 'Volume': 'null', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be511'), 'Date': '13/06/2000', 'Open': '9.333333', 'High': '9.77', 'Low': '9.166666', 'Close': '9.693333', 'Adj Close': '6.979023', 'Volume': '2567925', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be512'), 'Date': '14/06/2000', 'Open': '9.666666', 'High': '9.687333', 'Low': '9.633333', 'Close': '9.687333', 'Adj Close': '6.974704', 'Volume': '1515588', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be513'), 'Date': '15/06/2000', 'Open': '9.733333', 'High': '10.093333', 'Low': '9.733333', 'Close': '10', 'Adj Close': '7.19982', 'Volume': '1963995', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be514'), 'Date': '16/06/2000', 'Open': '10', 'High': '10.5', 'Low': '10', 'Close': '10.133333', 'Adj Close': '7.295815', 'Volume': '1428390', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be515'), 'Date': '19/06/2000', 'Open': '10', 'High': '10.136666', 'Low': '10', 'Close': '10.066666', 'Adj Close': '7.247818', 'Volume': '1012647', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be516'), 'Date': '20/06/2000', 'Open': '10.002', 'High': '10.066666', 'Low': '9.9', 'Close': '10.033333', 'Adj Close': '7.223818', 'Volume': '995220', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be517'), 'Date': '21/06/2000', 'Open': '10.003', 'High': '10.333333', 'Low': '10', 'Close': '10.333333', 'Adj Close': '7.439813', 'Volume': '553188', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be518'), 'Date': '22/06/2000', 'Open': '10.502666', 'High': '11.033333', 'Low': '10.35', 'Close': '10.807666', 'Adj Close': '7.781324', 'Volume': '1567623', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be519'), 'Date': '23/06/2000', 'Open': '10.780666', 'High': '11.203333', 'Low': '10.780666', 'Close': '11.174333', 'Adj Close': '8.045319', 'Volume': '1692561', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be51a'), 'Date': '26/06/2000', 'Open': '11.183333', 'High': '11.363333', 'Low': '11.1', 'Close': '11.316666', 'Adj Close': '8.147797', 'Volume': '1478388', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be51b'), 'Date': '27/06/2000', 'Open': '11.338', 'High': '11.593333', 'Low': '11.236666', 'Close': '11.298333', 'Adj Close': '8.134596', 'Volume': '2256255', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be51c'), 'Date': '28/06/2000', 'Open': '10.988666', 'High': '11', 'Low': '10.6', 'Close': '10.904', 'Adj Close': '7.850684', 'Volume': '2177307', 'SENTIMENT': 'NEGATIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be51d'), 'Date': '29/06/2000', 'Open': '10.887333', 'High': '10.887333', 'Low': '10.5', 'Close': '10.55', 'Adj Close': '7.59581', 'Volume': '811515', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be51e'), 'Date': '30/06/2000', 'Open': '10.332333', 'High': '11.011666', 'Low': '10.332333', 'Close': '11.011666', 'Adj Close': '7.928201', 'Volume': '1864875', 'SENTIMENT': 'POSITIVE', 'RBA': '6', 'FED': '6.86'}
# {'_id': ObjectId('62653091f0a054097b5be51f'), 'Date': '3/07/2000', 'Open': '10.695', 'High': '11.45', 'Low': '10.695', 'Close': '11.432', 'Adj Close': '8.230832', 'Volume': '1517391', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be520'), 'Date': '4/07/2000', 'Open': '11.316666', 'High': '11.483333', 'Low': '11.083333', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '990279', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be521'), 'Date': '5/07/2000', 'Open': '11.333333', 'High': '11.366666', 'Low': '11.166666', 'Close': '11.3', 'Adj Close': '8.135795', 'Volume': '1069248', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be522'), 'Date': '6/07/2000', 'Open': '11.136666', 'High': '11.15', 'Low': '11.066666', 'Close': '11.106', 'Adj Close': '7.996118', 'Volume': '649389', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be523'), 'Date': '7/07/2000', 'Open': '11.116666', 'High': '11.326666', 'Low': '11.11', 'Close': '11.111666', 'Adj Close': '8.000198', 'Volume': '829698', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be524'), 'Date': '10/07/2000', 'Open': '11.121666', 'High': '11.333333', 'Low': '11.121666', 'Close': '11.3', 'Adj Close': '8.135795', 'Volume': '625728', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be525'), 'Date': '11/07/2000', 'Open': '11.3', 'High': '11.34', 'Low': '11.293333', 'Close': '11.303333', 'Adj Close': '8.138192', 'Volume': '795117', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be526'), 'Date': '12/07/2000', 'Open': '11.239333', 'High': '11.3', 'Low': '11.133333', 'Close': '11.133333', 'Adj Close': '8.015798', 'Volume': '814278', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be527'), 'Date': '13/07/2000', 'Open': '11.135', 'High': '11.266666', 'Low': '11.033333', 'Close': '11.233333', 'Adj Close': '8.087796', 'Volume': '277344', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be528'), 'Date': '14/07/2000', 'Open': '11.190666', 'High': '11.333333', 'Low': '11.190666', 'Close': '11.293333', 'Adj Close': '8.130997', 'Volume': '891420', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be529'), 'Date': '17/07/2000', 'Open': '11.295', 'High': '11.366666', 'Low': '11.166666', 'Close': '11.329333', 'Adj Close': '8.156916', 'Volume': '1259106', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be52a'), 'Date': '18/07/2000', 'Open': '11.3', 'High': '11.333333', 'Low': '11.263333', 'Close': '11.302333', 'Adj Close': '8.137476', 'Volume': '688809', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be52b'), 'Date': '19/07/2000', 'Open': '11.270333', 'High': '11.433333', 'Low': '11.270333', 'Close': '11.401', 'Adj Close': '8.208515', 'Volume': '1103241', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be52c'), 'Date': '20/07/2000', 'Open': '11.301', 'High': '11.5', 'Low': '11.301', 'Close': '11.483666', 'Adj Close': '8.268032', 'Volume': '410355', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be52d'), 'Date': '21/07/2000', 'Open': '11.5', 'High': '11.5', 'Low': '11.333333', 'Close': '11.36', 'Adj Close': '8.178996', 'Volume': '790554', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be52e'), 'Date': '24/07/2000', 'Open': '11.308666', 'High': '11.366666', 'Low': '11.266666', 'Close': '11.365', 'Adj Close': '8.182593', 'Volume': '830796', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be52f'), 'Date': '25/07/2000', 'Open': '11.333333', 'High': '11.43', 'Low': '11.303333', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '487569', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be530'), 'Date': '26/07/2000', 'Open': '11.306666', 'High': '11.396666', 'Low': '11.306666', 'Close': '11.371666', 'Adj Close': '8.187391', 'Volume': '917904', 'SENTIMENT': 'POSITIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be531'), 'Date': '27/07/2000', 'Open': '11.383333', 'High': '11.55', 'Low': '11.383333', 'Close': '11.466666', 'Adj Close': '8.255795', 'Volume': '1001859', 'SENTIMENT': 'NEGATIVE', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be532'), 'Date': '28/07/2000', 'Open': '11.333333', 'High': '11.35', 'Low': '11.316666', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '522087', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be533'), 'Date': '31/07/2000', 'Open': '11.266666', 'High': '11.333333', 'Low': '11.166666', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '1040352', 'SENTIMENT': 'NEUTRAL', 'RBA': '5.99', 'FED': '6.64'}
# {'_id': ObjectId('62653091f0a054097b5be534'), 'Date': '1/08/2000', 'Open': '11.333333', 'High': '11.35', 'Low': '11.2', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '965700', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be535'), 'Date': '2/08/2000', 'Open': '11.333333', 'High': '11.4', 'Low': '11.3', 'Close': '11.336666', 'Adj Close': '8.162194', 'Volume': '818703', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be536'), 'Date': '3/08/2000', 'Open': '11.4', 'High': '11.4', 'Low': '11.283333', 'Close': '11.306666', 'Adj Close': '8.140594', 'Volume': '1106490', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be537'), 'Date': '4/08/2000', 'Open': '11.333333', 'High': '11.366666', 'Low': '11.313333', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '737526', 'SENTIMENT': 'NEUTRAL', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be538'), 'Date': '7/08/2000', 'Open': '11.333333', 'High': '11.343333', 'Low': '11.316666', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '543000', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be539'), 'Date': '8/08/2000', 'Open': '11.361666', 'High': '11.383333', 'Low': '11.333333', 'Close': '11.339', 'Adj Close': '8.163875', 'Volume': '762471', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be53a'), 'Date': '9/08/2000', 'Open': '11.333333', 'High': '11.466666', 'Low': '11.333333', 'Close': '11.466666', 'Adj Close': '8.255795', 'Volume': '475374', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be53b'), 'Date': '10/08/2000', 'Open': '11.464666', 'High': '11.496666', 'Low': '11.396666', 'Close': '11.4', 'Adj Close': '8.207792', 'Volume': '610152', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be53c'), 'Date': '11/08/2000', 'Open': '11.433333', 'High': '11.433333', 'Low': '11.333333', 'Close': '11.333333', 'Adj Close': '8.159795', 'Volume': '727050', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be53d'), 'Date': '14/08/2000', 'Open': '11.333333', 'High': '11.496666', 'Low': '11.333333', 'Close': '11.477666', 'Adj Close': '8.26371', 'Volume': '248688', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be53e'), 'Date': '15/08/2000', 'Open': '11.483', 'High': '12.016666', 'Low': '11.483', 'Close': '11.898333', 'Adj Close': '8.566583', 'Volume': '356466', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be53f'), 'Date': '16/08/2000', 'Open': '11.886666', 'High': '11.886666', 'Low': '11.516666', 'Close': '11.666666', 'Adj Close': '8.399789', 'Volume': '488625', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be540'), 'Date': '17/08/2000', 'Open': '11.666666', 'High': '11.8', 'Low': '11.65', 'Close': '11.8', 'Adj Close': '8.495788', 'Volume': '808872', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be541'), 'Date': '18/08/2000', 'Open': '11.803', 'High': '12', 'Low': '11.766666', 'Close': '11.783333', 'Adj Close': '8.483788', 'Volume': '538149', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be542'), 'Date': '21/08/2000', 'Open': '11.8', 'High': '11.9', 'Low': '11.73', 'Close': '11.8', 'Adj Close': '8.495788', 'Volume': '397731', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be543'), 'Date': '22/08/2000', 'Open': '11.783333', 'High': '11.9', 'Low': '11.783333', 'Close': '11.83', 'Adj Close': '8.517385', 'Volume': '474306', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be544'), 'Date': '23/08/2000', 'Open': '11.853333', 'High': '11.906666', 'Low': '11.733333', 'Close': '11.846666', 'Adj Close': '8.529387', 'Volume': '1027356', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be545'), 'Date': '24/08/2000', 'Open': '11.869', 'High': '12.333333', 'Low': '11.869', 'Close': '12.2', 'Adj Close': '8.783778', 'Volume': '1238919', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be546'), 'Date': '25/08/2000', 'Open': '12.326666', 'High': '12.35', 'Low': '12.186666', 'Close': '12.333333', 'Adj Close': '8.879778', 'Volume': '671481', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be547'), 'Date': '28/08/2000', 'Open': '12.366666', 'High': '12.433333', 'Low': '12.233333', 'Close': '12.266666', 'Adj Close': '8.831776', 'Volume': '389940', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be548'), 'Date': '29/08/2000', 'Open': '12.333333', 'High': '12.383333', 'Low': '12.27', 'Close': '12.3', 'Adj Close': '8.855778', 'Volume': '573861', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be549'), 'Date': '30/08/2000', 'Open': '12.3', 'High': '12.3', 'Low': '12', 'Close': '12.119333', 'Adj Close': '8.725699', 'Volume': '460311', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be54a'), 'Date': '31/08/2000', 'Open': '12.102', 'High': '12.102', 'Low': '11.75', 'Close': '11.842333', 'Adj Close': '8.526266', 'Volume': '710832', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.65'}
# {'_id': ObjectId('62653091f0a054097b5be54b'), 'Date': '1/09/2000', 'Open': '11.852666', 'High': '11.866666', 'Low': '11.636666', 'Close': '11.683333', 'Adj Close': '8.411788', 'Volume': '759840', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be54c'), 'Date': '4/09/2000', 'Open': '11.676666', 'High': '11.833333', 'Low': '11.666666', 'Close': '11.698333', 'Adj Close': '8.422588', 'Volume': '1344159', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be54d'), 'Date': '5/09/2000', 'Open': '11.7', 'High': '12', 'Low': '11.7', 'Close': '11.994666', 'Adj Close': '8.635939', 'Volume': '255645', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be54e'), 'Date': '6/09/2000', 'Open': '11.991', 'High': '11.991', 'Low': '11.75', 'Close': '11.758333', 'Adj Close': '8.465787', 'Volume': '1479120', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be54f'), 'Date': '7/09/2000', 'Open': '11.783333', 'High': '11.786666', 'Low': '11.703333', 'Close': '11.766666', 'Adj Close': '8.471786', 'Volume': '547920', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be550'), 'Date': '8/09/2000', 'Open': '11.766666', 'High': '11.916666', 'Low': '11.733333', 'Close': '11.813333', 'Adj Close': '8.505389', 'Volume': '229173', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be551'), 'Date': '11/09/2000', 'Open': '11.829', 'High': '12.083333', 'Low': '11.829', 'Close': '11.933333', 'Adj Close': '8.591784', 'Volume': '808383', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be552'), 'Date': '12/09/2000', 'Open': '11.951666', 'High': '12', 'Low': '11.866666', 'Close': '11.9', 'Adj Close': '8.567786', 'Volume': '486270', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be553'), 'Date': '13/09/2000', 'Open': '11.902666', 'High': '12', 'Low': '11.873333', 'Close': '11.996666', 'Adj Close': '8.637382', 'Volume': '1036476', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be554'), 'Date': '14/09/2000', 'Open': '11.983333', 'High': '12.1', 'Low': '11.966666', 'Close': '12.033333', 'Adj Close': '8.663777', 'Volume': '598035', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be555'), 'Date': '15/09/2000', 'Open': '12.036666', 'High': '12.066666', 'Low': '11.866666', 'Close': '12', 'Adj Close': '8.639781', 'Volume': '723816', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be556'), 'Date': '18/09/2000', 'Open': '11.994333', 'High': '11.994333', 'Low': '11.666666', 'Close': '11.7', 'Adj Close': '8.423787', 'Volume': '475542', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be557'), 'Date': '19/09/2000', 'Open': '11.666666', 'High': '11.666666', 'Low': '11.133333', 'Close': '11.16', 'Adj Close': '8.034996', 'Volume': '1258485', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be558'), 'Date': '20/09/2000', 'Open': '11.113333', 'High': '11.35', 'Low': '11.003333', 'Close': '11.35', 'Adj Close': '8.171793', 'Volume': '1177020', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be559'), 'Date': '21/09/2000', 'Open': '11.35', 'High': '11.633333', 'Low': '11.35', 'Close': '11.59', 'Adj Close': '8.344589', 'Volume': '1342197', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be55a'), 'Date': '22/09/2000', 'Open': '11.328', 'High': '11.4', 'Low': '11.173333', 'Close': '11.233333', 'Adj Close': '8.122838', 'Volume': '1181556', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be55b'), 'Date': '25/09/2000', 'Open': '11.366666', 'High': '11.466666', 'Low': '11.35', 'Close': '11.433333', 'Adj Close': '8.267456', 'Volume': '649707', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be55c'), 'Date': '26/09/2000', 'Open': '11.433333', 'High': '11.45', 'Low': '11.4', 'Close': '11.416666', 'Adj Close': '8.255407', 'Volume': '770097', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be55d'), 'Date': '27/09/2000', 'Open': '11.416666', 'High': '11.416666', 'Low': '11.163666', 'Close': '11.163666', 'Adj Close': '8.072463', 'Volume': '327267', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be55e'), 'Date': '28/09/2000', 'Open': '11.160333', 'High': '11.160333', 'Low': '10.583333', 'Close': '11', 'Adj Close': '7.954113', 'Volume': '747318', 'SENTIMENT': 'POSITIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be55f'), 'Date': '29/09/2000', 'Open': '11.02', 'High': '11.57', 'Low': '11.02', 'Close': '11.566666', 'Adj Close': '8.363873', 'Volume': '733767', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.24', 'FED': '6.6'}
# {'_id': ObjectId('62653091f0a054097b5be560'), 'Date': '2/10/2000', 'Open': '11.555666', 'High': '11.566666', 'Low': '11.416666', 'Close': '11.533333', 'Adj Close': '8.33977', 'Volume': '195522', 'SENTIMENT': 'NEGATIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'_id': ObjectId('62653091f0a054097b5be561'), 'Date': '3/10/2000', 'Open': '11.5', 'High': '11.506666', 'Low': '11.066666', 'Close': '11.164333', 'Adj Close': '8.072946', 'Volume': '1259451', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# {'_id': ObjectId('62653091f0a054097b5be562'), 'Date': '4/10/2000', 'Open': '11.166666', 'High': '11.166666', 'Low': '11.066666', 'Close': '11.166666', 'Adj Close': '8.074632', 'Volume': '532506', 'SENTIMENT': 'POSITIVE', 'RBA': '6.23', 'FED': '6.59'}
# ...
# {'_id': ObjectId('62653093f0a054097b5bfa8d'), 'Date': '19/01/2022', 'Open': '271.790009', 'High': '273.459991', 'Low': '270.049988', 'Close': '270.399994', 'Adj Close': '268.910431', 'Volume': '951762', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa8e'), 'Date': '20/01/2022', 'Open': '273.160004', 'High': '274.619995', 'Low': '268.519989', 'Close': '271.25', 'Adj Close': '269.755768', 'Volume': '925145', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa8f'), 'Date': '21/01/2022', 'Open': '268.640015', 'High': '271.679993', 'Low': '263.269989', 'Close': '264.519989', 'Adj Close': '263.062836', 'Volume': '1707384', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa90'), 'Date': '24/01/2022', 'Open': '263.980011', 'High': '266.170013', 'Low': '261.799988', 'Close': '262.570007', 'Adj Close': '261.123596', 'Volume': '718907', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa91'), 'Date': '25/01/2022', 'Open': '261.179993', 'High': '262.399994', 'Low': '255.600006', 'Close': '258.350006', 'Adj Close': '256.926819', 'Volume': '1556357', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa92'), 'Date': '27/01/2022', 'Open': '260.190002', 'High': '262.26001', 'Low': '245.330002', 'Close': '249.429993', 'Adj Close': '248.055954', 'Volume': '1741008', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa93'), 'Date': '28/01/2022', 'Open': '254.949997', 'High': '258.73999', 'Low': '251.729996', 'Close': '257.51001', 'Adj Close': '256.091461', 'Volume': '3996379', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa94'), 'Date': '31/01/2022', 'Open': '258.01001', 'High': '261.519989', 'Low': '255.5', 'Close': '260.350006', 'Adj Close': '258.915802', 'Volume': '1048060', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa95'), 'Date': '1/02/2022', 'Open': '262.880005', 'High': '264', 'Low': '258.959991', 'Close': '261.549988', 'Adj Close': '260.109192', 'Volume': '693901', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa96'), 'Date': '2/02/2022', 'Open': '263.850006', 'High': '264.26001', 'Low': '259.649994', 'Close': '262.420013', 'Adj Close': '260.974426', 'Volume': '574148', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa97'), 'Date': '3/02/2022', 'Open': '257.769989', 'High': '260.269989', 'Low': '255.5', 'Close': '257.459991', 'Adj Close': '256.041718', 'Volume': '818830', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa98'), 'Date': '4/02/2022', 'Open': '257.450012', 'High': '260.839996', 'Low': '255.660004', 'Close': '258.790009', 'Adj Close': '257.36441', 'Volume': '783457', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa99'), 'Date': '7/02/2022', 'Open': '255.699997', 'High': '257.649994', 'Low': '254.199997', 'Close': '254.610001', 'Adj Close': '253.207428', 'Volume': '684663', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa9a'), 'Date': '8/02/2022', 'Open': '255', 'High': '259.410004', 'Low': '255', 'Close': '256.980011', 'Adj Close': '255.564377', 'Volume': '580276', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa9b'), 'Date': '9/02/2022', 'Open': '256.019989', 'High': '258.015015', 'Low': '251.5', 'Close': '255.610001', 'Adj Close': '254.20192', 'Volume': '1073196', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa9c'), 'Date': '10/02/2022', 'Open': '257.899994', 'High': '257.98999', 'Low': '252.880005', 'Close': '253.710007', 'Adj Close': '252.312393', 'Volume': '1018922', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa9d'), 'Date': '11/02/2022', 'Open': '250', 'High': '250.720001', 'Low': '247.5', 'Close': '248.5', 'Adj Close': '247.131088', 'Volume': '1403507', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa9e'), 'Date': '14/02/2022', 'Open': '246.509995', 'High': '246.899994', 'Low': '242.589996', 'Close': '243.559998', 'Adj Close': '242.218292', 'Volume': '1070030', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfa9f'), 'Date': '15/02/2022', 'Open': '241.800003', 'High': '244.300003', 'Low': '240.100006', 'Close': '243', 'Adj Close': '241.661377', 'Volume': '1291429', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa0'), 'Date': '16/02/2022', 'Open': '262.399994', 'High': '264.070007', 'Low': '256.609985', 'Close': '263.690002', 'Adj Close': '262.237396', 'Volume': '2334138', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa1'), 'Date': '17/02/2022', 'Open': '276.869995', 'High': '280', 'Low': '270.440002', 'Close': '277', 'Adj Close': '275.474091', 'Volume': '2491549', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa2'), 'Date': '18/02/2022', 'Open': '272.51001', 'High': '273.970001', 'Low': '265.570007', 'Close': '265.570007', 'Adj Close': '264.107056', 'Volume': '1738836', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa3'), 'Date': '21/02/2022', 'Open': '262.690002', 'High': '264.660004', 'Low': '260.559998', 'Close': '263.540009', 'Adj Close': '262.088226', 'Volume': '577306', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa4'), 'Date': '22/02/2022', 'Open': '262.049988', 'High': '266.980011', 'Low': '260.890015', 'Close': '266.980011', 'Adj Close': '265.509308', 'Volume': '983108', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa5'), 'Date': '23/02/2022', 'Open': '267.049988', 'High': '268.890015', 'Low': '265.089996', 'Close': '268.890015', 'Adj Close': '267.408783', 'Volume': '979362', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa6'), 'Date': '24/02/2022', 'Open': '269.98999', 'High': '269.98999', 'Low': '261.690002', 'Close': '264.790009', 'Adj Close': '263.33136', 'Volume': '1228768', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa7'), 'Date': '25/02/2022', 'Open': '269.019989', 'High': '269.019989', 'Low': '261', 'Close': '261.329987', 'Adj Close': '259.890381', 'Volume': '1067841', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa8'), 'Date': '28/02/2022', 'Open': '258.950012', 'High': '260.869995', 'Low': '256.440002', 'Close': '259.980011', 'Adj Close': '258.547852', 'Volume': '1127660', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaa9'), 'Date': '1/03/2022', 'Open': '259.359985', 'High': '264.140015', 'Low': '259.149994', 'Close': '261.100006', 'Adj Close': '259.661682', 'Volume': '951047', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaaa'), 'Date': '2/03/2022', 'Open': '255.279999', 'High': '263.5', 'Low': '255.139999', 'Close': '260.75', 'Adj Close': '259.313599', 'Volume': '950661', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaab'), 'Date': '3/03/2022', 'Open': '260', 'High': '263.950012', 'Low': '257.079987', 'Close': '257.5', 'Adj Close': '256.081512', 'Volume': '1220449', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaac'), 'Date': '4/03/2022', 'Open': '257', 'High': '258.529999', 'Low': '253.509995', 'Close': '258.299988', 'Adj Close': '256.877075', 'Volume': '996482', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaad'), 'Date': '7/03/2022', 'Open': '254.509995', 'High': '255.970001', 'Low': '248.970001', 'Close': '249.660004', 'Adj Close': '249.660004', 'Volume': '874716', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaae'), 'Date': '8/03/2022', 'Open': '251.800003', 'High': '259.549988', 'Low': '250.589996', 'Close': '256.649994', 'Adj Close': '256.649994', 'Volume': '911704', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaaf'), 'Date': '9/03/2022', 'Open': '258.920013', 'High': '259.140015', 'Low': '253.979996', 'Close': '257', 'Adj Close': '257', 'Volume': '663019', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab0'), 'Date': '10/03/2022', 'Open': '261.269989', 'High': '264.140015', 'Low': '258.079987', 'Close': '263', 'Adj Close': '263', 'Volume': '934165', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab1'), 'Date': '11/03/2022', 'Open': '265', 'High': '265.850006', 'Low': '256.170013', 'Close': '256.529999', 'Adj Close': '256.529999', 'Volume': '1148644', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab2'), 'Date': '14/03/2022', 'Open': '259.619995', 'High': '264.170013', 'Low': '258.600006', 'Close': '263.269989', 'Adj Close': '263.269989', 'Volume': '631755', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab3'), 'Date': '15/03/2022', 'Open': '263.410004', 'High': '265.450012', 'Low': '259.954987', 'Close': '263.769989', 'Adj Close': '263.769989', 'Volume': '505644', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab4'), 'Date': '16/03/2022', 'Open': '267.899994', 'High': '269.98999', 'Low': '266.209991', 'Close': '268.51001', 'Adj Close': '268.51001', 'Volume': '766792', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab5'), 'Date': '17/03/2022', 'Open': '274.73999', 'High': '274.73999', 'Low': '269', 'Close': '270.589996', 'Adj Close': '270.589996', 'Volume': '1079333', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab6'), 'Date': '18/03/2022', 'Open': '271.179993', 'High': '271.51001', 'Low': '267.079987', 'Close': '270.959991', 'Adj Close': '270.959991', 'Volume': '1964122', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab7'), 'Date': '21/03/2022', 'Open': '272.700012', 'High': '273.369995', 'Low': '266.880005', 'Close': '266.970001', 'Adj Close': '266.970001', 'Volume': '559816', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab8'), 'Date': '22/03/2022', 'Open': '268.040009', 'High': '269.959991', 'Low': '265.359985', 'Close': '265.359985', 'Adj Close': '265.359985', 'Volume': '589856', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfab9'), 'Date': '23/03/2022', 'Open': '266.299988', 'High': '268.940002', 'Low': '266.119995', 'Close': '267.519989', 'Adj Close': '267.519989', 'Volume': '754641', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaba'), 'Date': '24/03/2022', 'Open': '264.709991', 'High': '267.399994', 'Low': '263.660004', 'Close': '267.399994', 'Adj Close': '267.399994', 'Volume': '718769', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfabb'), 'Date': '25/03/2022', 'Open': '266.970001', 'High': '267.890015', 'Low': '264.51001', 'Close': '264.809998', 'Adj Close': '264.809998', 'Volume': '785020', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfabc'), 'Date': '28/03/2022', 'Open': '263.5', 'High': '263.970001', 'Low': '260.209991', 'Close': '261.859985', 'Adj Close': '261.859985', 'Volume': '476942', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfabd'), 'Date': '29/03/2022', 'Open': '263.779999', 'High': '267.149994', 'Low': '262.5', 'Close': '265.600006', 'Adj Close': '265.600006', 'Volume': '621353', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfabe'), 'Date': '30/03/2022', 'Open': '268.529999', 'High': '271.940002', 'Low': '267.820007', 'Close': '270.049988', 'Adj Close': '270.049988', 'Volume': '687777', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfabf'), 'Date': '31/03/2022', 'Open': '273.950012', 'High': '273.950012', 'Low': '268.149994', 'Close': '268.149994', 'Adj Close': '268.149994', 'Volume': '1152270', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac0'), 'Date': '1/04/2022', 'Open': '268', 'High': '268.929993', 'Low': '265.809998', 'Close': '266.279999', 'Adj Close': '266.279999', 'Volume': '835555', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac1'), 'Date': '4/04/2022', 'Open': '268', 'High': '270.450012', 'Low': '267.690002', 'Close': '267.690002', 'Adj Close': '267.690002', 'Volume': '469737', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac2'), 'Date': '5/04/2022', 'Open': '270.5', 'High': '271.100006', 'Low': '266.390015', 'Close': '268.529999', 'Adj Close': '268.529999', 'Volume': '546415', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac3'), 'Date': '6/04/2022', 'Open': '268.100006', 'High': '269.459991', 'Low': '266.5', 'Close': '267.540009', 'Adj Close': '267.540009', 'Volume': '517400', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac4'), 'Date': '7/04/2022', 'Open': '267.059998', 'High': '268.329987', 'Low': '266.279999', 'Close': '266.579987', 'Adj Close': '266.579987', 'Volume': '498246', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac5'), 'Date': '8/04/2022', 'Open': '269', 'High': '269', 'Low': '265.380005', 'Close': '265.720001', 'Adj Close': '265.720001', 'Volume': '514648', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac6'), 'Date': '11/04/2022', 'Open': '265.5', 'High': '266.549988', 'Low': '264.709991', 'Close': '265.470001', 'Adj Close': '265.470001', 'Volume': '502366', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac7'), 'Date': '12/04/2022', 'Open': '265', 'High': '265.019989', 'Low': '260.869995', 'Close': '261.970001', 'Adj Close': '261.970001', 'Volume': '566745', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac8'), 'Date': '13/04/2022', 'Open': '262', 'High': '264.109985', 'Low': '262', 'Close': '262.959991', 'Adj Close': '262.959991', 'Volume': '585733', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfac9'), 'Date': '14/04/2022', 'Open': '262.959991', 'High': '265.459991', 'Low': '262.049988', 'Close': '264.950012', 'Adj Close': '264.950012', 'Volume': '805253', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfaca'), 'Date': '19/04/2022', 'Open': '263', 'High': '264.589996', 'Low': '261.579987', 'Close': '262.350006', 'Adj Close': '262.350006', 'Volume': '700468', 'SENTIMENT': 'POSITIVE', 'RBA': '0.05', 'FED': '0.08'}
# {'_id': ObjectId('62653093f0a054097b5bfacb'), 'Date': '20/04/2022', 'Open': '266.100006', 'High': '267.98999', 'Low': '263.700012', 'Close': '264.5', 'Adj Close': '264.5', 'Volume': '857150', 'SENTIMENT': 'NEGATIVE', 'RBA': '0.05', 'FED': '0.08'}
