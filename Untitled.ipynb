# %%
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# %%
#Reading the CSV source file into pandas via pd.read_csv method
csv_file = "atlassian_csl_financials1.csv"
acf= pd.read_csv(csv_file)
acf
# Out:
#                                            ITEM Year_End         CSL  \
# 0                                       Revenue  TTM2022  10,477,000
# 1                                       Revenue     2021  10,265,300
# 2                                       Revenue     2020   9,100,500
# 3                                       Revenue     2019   8,509,900
# 4                                       Revenue     2018   7,587,900
# ..                                          ...      ...         ...
# 206                  Total stockholders' equity     2018   4,079,900
# 207  Total liabilities and stockholders' equity     2021  18,156,900
# 208  Total liabilities and stockholders' equity     2020  15,464,600
# 209  Total liabilities and stockholders' equity     2019  12,314,400
# 210  Total liabilities and stockholders' equity     2018  10,774,500
#
#      ATLASSIAN
# 0    2,430,817
# 1    2,089,132
# 2    1,614,173
# 3    1,210,127
# 4      873,950
# ..         ...
# 206    892,766
# ...

# %%
acf['ITEM'].value_counts()
# Out:
# Basic EPS                                      5
# Revenue                                        5
# Net income available to common shareholders    5
# Interest expense                               5
# EBITDA                                         5
# Net income                                     5
# Total other income/expenses net                5
# Income before tax                              5
# Cost of revenue                                5
# Income tax expense                             5
# Selling general and administrative             5
# Total operating expenses                       5
# Operating expenses                             5
# Basic average shares                           5
# Gross profit                                   5
# Diluted EPS                                    5
# Operating income or loss                       5
# Diluted average shares                         5
# Income from continuing operations              5
# ...

# %%
acf.style.highlight_null(null_color='red')
# Out:
# <style  type="text/css" >
# </style><table id="T_a37f4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ITEM</th>        <th class="col_heading level0 col1" >Year_End</th>        <th class="col_heading level0 col2" >CSL</th>        <th class="col_heading level0 col3" >ATLASSIAN</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a37f4_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a37f4_row0_col0" class="data row0 col0" >Revenue</td>
#                         <td id="T_a37f4_row0_col1" class="data row0 col1" >TTM2022</td>
#                         <td id="T_a37f4_row0_col2" class="data row0 col2" >10,477,000</td>
#                         <td id="T_a37f4_row0_col3" class="data row0 col3" >2,430,817</td>
#             </tr>
#             <tr>
#                         <th id="T_a37f4_level0_row1" class="row_heading level0 row1" >1</th>
# ...
